# %%
import requests
import json
import re
import sys
from bs4 import BeautifulSoup

soup = BeautifulSoup('html.parser')
soup
# Out:
# <html><body><p>html.parser</p></body></html>

# %%
# 경기도 31개 시/군 법정동 코드 (앞 5자리)
GYEONGGI_DISTRICTS = {
    "가평군": "41820",
    "고양시 덕양구": "41281",
    "고양시 일산동구": "41285",
    "고양시 일산서구": "41287",
    "과천시": "41290",
    "광명시": "41210",
    "광주시": "41610",
    "구리시": "41310",
    "군포시": "41410",
    "김포시": "41570",
    "남양주시": "41360",
    "동두천시": "41250",
    "부천시": "41190",
    "성남시 분당구": "41135",
    "성남시 수정구": "41131",
    "성남시 중원구": "41133",
    "수원시 권선구": "41115",
    "수원시 영통구": "41117",
    "수원시 장안구": "41111",
    "수원시 팔달구": "41113",
    "시흥시": "41390",
    "안산시 단원구": "41273",
    "안산시 상록구": "41271",
    "안성시": "41550",
    "안양시 동안구": "41173",
    "안양시 만안구": "41171",
    "양주시": "41630",
    "양평군": "41830",
    "여주시": "41670",
    "연천군": "41800",
    "오산시": "41370",
    "용인시 기흥구": "41463",
    "용인시 수지구": "41465",
    "용인시 처인구": "41461",
    "의왕시": "41430",
    "의정부시": "41150",
    "이천시": "41500",
    "파주시": "41480",
    "평택시": "41220",
    "포천시": "41650",
    "하남시": "41450",
    "화성시": "41590"
}

# # 인천광역시 10개 구/군 법정동 코드 (앞 5자리)
# INCHEON_DISTRICTS = {
#     "강화군": "28710",
#     "계양구": "28245",
#     "남동구": "28200",
#     "동구": "28140",
#     "미추홀구": "28177",  # (구)남구
#     "부평구": "28237",
#     "서구": "28260",
#     "연수구": "28185",
#     "옹진군": "28720",
#     "중구": "28110"
# }

# %%
import time
import requests
from bs4 import BeautifulSoup
import pandas as pd

BASE_URL = "http://apis.data.go.kr/1613000/RTMSDataSvcAptTradeDev/getRTMSDataSvcAptTradeDev"
SERVICE_KEY = "YPxXvm/3jO5hggkbdJFWnhh8IC3VdMlkRvZHh1pkG8eZxXw12ymm4OAW10urfUVN++TzkurcrZ5Os3Gr9P8Kwg=="
URL = f"{BASE_URL}"

# 경기도 구별 데이터 저장할 딕셔너리
gg_real_estate_data = {}

# 크롤링할 기간 설정
start_year = 2025
start_month = 1
end_year = 2025
end_month = 2

# 서울시 각 구별 데이터 요청
# for 서울, 인천, 경기 
# for 연월

for year in range(start_year, end_year + 1):
    for month in range(1, 13):
        if year == start_year and month < start_month:
            continue
        if year == end_year and month > end_month:
            break

        deal_ymd = f"{year}{month:02}"  # 거래 연월 (YYYYMM 형식)
        print(f"⏳ {deal_ymd} 데이터 수집 시작")
    
    # 각 구별 데이터 요청       
    for gu, code in GYEONGGI_DISTRICTS.items():
        print(f"📌 {gu} ({code}) 데이터 요청 중...")

        params = {
            "LAWD_CD": code,
            "DEAL_YMD": deal_ymd,  # 거래 연월
            "serviceKey": SERVICE_KEY,
            "pageNo": 1,
            "numOfRows": 999
        }

        response = requests.get(URL, params=params)
        response.encoding = "utf-8"
        response.text
        
        # 응답 상태 코드 체크
        if response.status_code == 200:
            print(f"✅ {gu} 응답 상태: {response.status_code}")
            soup = BeautifulSoup(response.text, "xml")

            # 응답 XML 구조 확인
            print(f"📊 {gu} 응답 데이터 샘플:")
            print(soup.prettify()[:1000])  # 데이터 일부 출력해서 확인

            # 'item' 태그가 있는지 확인
            items = soup.find_all("item")
            if not items:
                print(f"⚠️ {gu}에 거래 데이터가 없습니다.")
            else:
                gg_real_estate_data[gu] = items
                print(f"✅ {gu} 데이터 수집 완료 ({len(items)}건)")

                # 데이터 추출 및 검증
                all_data = []  # 구별 데이터 리스트 초기화
                for item in items:
                    data = {
                        "구": gu,
                        "거래금액": item.find("거래금액").text.strip() if item.find("거래금액") else None,
                        "건축년도": item.find("건축년도").text.strip() if item.find("건축년도") else None,
                        "법정동": item.find("법정동").text.strip() if item.find("법정동") else None,
                        "아파트": item.find("아파트").text.strip() if item.find("아파트") else None,
                        "전용면적": item.find("전용면적").text.strip() if item.find("전용면적") else None,
                        "층": item.find("층").text.strip() if item.find("층") else None,
                        "거래일": f"{item.find('년').text}-{item.find('월').text}-{item.find('일').text}"
                        if item.find('년') and item.find('월') and item.find('일') else None
                    }

                    # 데이터 유효성 검사
                    if None not in data.values():  # 모든 값이 유효한 경우에만 리스트에 추가
                        all_data.append(data)

                # DataFrame 변환
                if all_data:
                    df = pd.DataFrame(all_data)
                    print(f"✅ {gu} DataFrame 생성 완료")
                    print(df.head())

        else:
            print(f"❌ {gu} 요청 실패 (Status Code: {response.status_code})")
        
        time.sleep(0.5)  # API 요청 간격 조절

print("📦 데이터 수집 완료")
# Out:
# ⏳ 202501 데이터 수집 시작
# ⏳ 202502 데이터 수집 시작
# 📌 가평군 (41820) 데이터 요청 중...
# ✅ 가평군 응답 상태: 200
# 📊 가평군 응답 데이터 샘플:
# <?xml version="1.0" encoding="utf-8"?>
# <response>
#  <header>
#   <resultCode>
#    000
#   </resultCode>
#   <resultMsg>
#    OK
#   </resultMsg>
#  </header>
#  <body>
#   <items>
#    <item>
#     <aptDong>
#     </aptDong>
#     <aptNm>
#      청평삼성쉐르빌
#     </aptNm>
#     <aptSeq>
#      41820-334
#     </aptSeq>
#     <bonbun>
#      0837
#     </bonbun>
#     <bubun>
#      0000
#     </bubun>
#     <buildYear>
#      2012
#     </buildYear>
#     <buyerGbn>
#      개인
#     </buyerGbn>
#     <cdealDay>
#     </cdealDay>
#     <cdealType>
#     </cdealType>
#     <dealAmount>
#      26,000
#     </dealAmount>
#     <dealDay>
#      18
#     </dealDay>
#     <dealMonth>
#      2
#     </dealMonth>
#     <dealYear>
#      2025
#     </dealYear>
#     <dealingGbn>
#      중개거래
#     </dealingGbn>
#     <estateAgentSggNm>
#      경기 가평군
#     </estateAgentSggNm>
#     <excluUseAr>
#      84.66
#     </excluUseAr>
#     <floor>
#      10
#     </floor>
#     <jibun>
#      837
#     </jibun>
#     <landCd>
#      1
#     </landCd>
#     <landLeaseholdGbn>
#      N
#     </landLeaseholdGbn>
#     <rgstDate>
#     </rgstDate>
#
# ✅ 가평군 데이터 수집 완료 (24건)
# 📌 고양시 덕양구 (41281) 데이터 요청 중...
# ✅ 고양시 덕양구 응답 상태: 200
# 📊 고양시 덕양구 응답 데이터 샘플:
# <?xml version="1.0" encoding="utf-8"?>
# <response>
#  <header>
#   <resultCode>
#    000
#   </resultCode>
#   <resultMsg>
#    OK
#   </resultMsg>
#  </header>
#  <body>
#   <items>
#    <item>
#     <aptDong>
#     </aptDong>
#     <aptNm>
#      삼성래미안
#     </aptNm>
#     <aptSeq>
#      41281-2113
#     </aptSeq>
#     <bonbun>
#      0860
#     </bonbun>
#     <bubun>
#      0000
#     </bubun>
#     <buildYear>
#      2009
#     </buildYear>
#     <buyerGbn>
#      개인
#     </buyerGbn>
#     <cdealDay>
#     </cdealDay>
#     <cdealType>
#     </cdealType>
#     <dealAmount>
#      63,500
#     </dealAmount>
#     <dealDay>
#      24
#     </dealDay>
#     <dealMonth>
#      2
#     </dealMonth>
#     <dealYear>
#      2025
#     </dealYear>
#     <dealingGbn>
#      중개거래
#     </dealingGbn>
#     <estateAgentSggNm>
#      경기 고양시 덕양구
#     </estateAgentSggNm>
#     <excluUseAr>
#      84.99
#     </excluUseAr>
#     <floor>
#      10
#     </floor>
#     <jibun>
#      860
#     </jibun>
#     <landCd>
#      1
#     </landCd>
#     <landLeaseholdGbn>
#      N
#     </landLeaseholdGbn>
#     <rgstDate>
#     </rgstDat
# ✅ 고양시 덕양구 데이터 수집 완료 (284건)
# 📌 고양시 일산동구 (41285) 데이터 요청 중...
# ✅ 고양시 일산동구 응답 상태: 200
# 📊 고양시 일산동구 응답 데이터 샘플:
# <?xml version="1.0" encoding="utf-8"?>
# <response>
#  <header>
#   <resultCode>
#    000
#   </resultCode>
#   <resultMsg>
#    OK
#   </resultMsg>
#  </header>
#  <body>
#   <items>
#    <item>
#     <aptDong>
#     </aptDong>
#     <aptNm>
#      위시티휴먼빌
#     </aptNm>
#     <aptSeq>
#      41285-361
#     </aptSeq>
#     <bonbun>
#      1533
#     </bonbun>
#     <bubun>
#      0000
#     </bubun>
#     <buildYear>
#      2014
#     </buildYear>
#     <buyerGbn>
#      개인
#     </buyerGbn>
#     <cdealDay>
#     </cdealDay>
#     <cdealType>
#     </cdealType>
#     <dealAmount>
#      55,000
#     </dealAmount>
#     <dealDay>
#      24
#     </dealDay>
#     <dealMonth>
#      2
#     </dealMonth>
#     <dealYear>
#      2025
#     </dealYear>
#     <dealingGbn>
#      중개거래
#     </dealingGbn>
#     <estateAgentSggNm>
#      경기 부천시 원미구
#     </estateAgentSggNm>
#     <excluUseAr>
#      117.41
#     </excluUseAr>
#     <floor>
#      23
#     </floor>
#     <jibun>
#      1533
#     </jibun>
#     <landCd>
#      1
#     </landCd>
#     <landLeaseholdGbn>
#      N
#     </landLeaseholdGbn>
#     <rgstDate>
#     </rgstD
# ✅ 고양시 일산동구 데이터 수집 완료 (151건)
# 📌 고양시 일산서구 (41287) 데이터 요청 중...
# ✅ 고양시 일산서구 응답 상태: 200
# 📊 고양시 일산서구 응답 데이터 샘플:
# <?xml version="1.0" encoding="utf-8"?>
# <response>
#  <header>
#   <resultCode>
#    000
#   </resultCode>
#   <resultMsg>
#    OK
#   </resultMsg>
#  </header>
#  <body>
#   <items>
#    <item>
#     <aptDong>
#     </aptDong>
#     <aptNm>
#      한화 포레나 킨텍스
#     </aptNm>
#     <aptSeq>
#      41287-596
#     </aptSeq>
#     <bonbun>
#      2603
#     </bonbun>
#     <bubun>
#      0000
#     </bubun>
#     <buildYear>
#      2019
#     </buildYear>
#     <buyerGbn>
#      개인
#     </buyerGbn>
#     <cdealDay>
#     </cdealDay>
#     <cdealType>
#     </cdealType>
#     <dealAmount>
#      108,500
#     </dealAmount>
#     <dealDay>
#      16
#     </dealDay>
#     <dealMonth>
#      2
#     </dealMonth>
#     <dealYear>
#      2025
#     </dealYear>
#     <dealingGbn>
#      중개거래
#     </dealingGbn>
#     <estateAgentSggNm>
#      경기 고양시 일산서구
#     </estateAgentSggNm>
#     <excluUseAr>
#      84.4278
#     </excluUseAr>
#     <floor>
#      39
#     </floor>
#     <jibun>
#      2603
#     </jibun>
#     <landCd>
#      1
#     </landCd>
#     <landLeaseholdGbn>
#      N
#     </landLeaseholdGbn>
#     <rgstDate>
#
# ✅ 고양시 일산서구 데이터 수집 완료 (211건)
# 📌 과천시 (41290) 데이터 요청 중...
# ✅ 과천시 응답 상태: 200
# 📊 과천시 응답 데이터 샘플:
# <?xml version="1.0" encoding="utf-8"?>
# <response>
#  <header>
#   <resultCode>
#    000
#   </resultCode>
#   <resultMsg>
#    OK
#   </resultMsg>
#  </header>
#  <body>
#   <items>
#    <item>
#     <aptDong>
#     </aptDong>
#     <aptNm>
#      센트럴파크푸르지오써밋
#     </aptNm>
#     <aptSeq>
#      41290-435
#     </aptSeq>
#     <bonbun>
#      0096
#     </bonbun>
#     <bubun>
#      0000
#     </bubun>
#     <buildYear>
#      2020
#     </buildYear>
#     <buyerGbn>
#      개인
#     </buyerGbn>
#     <cdealDay>
#     </cdealDay>
#     <cdealType>
#     </cdealType>
#     <dealAmount>
#      170,500
#     </dealAmount>
#     <dealDay>
#      26
#     </dealDay>
#     <dealMonth>
#      2
#     </dealMonth>
#     <dealYear>
#      2025
#     </dealYear>
#     <dealingGbn>
#      직거래
#     </dealingGbn>
#     <estateAgentSggNm>
#     </estateAgentSggNm>
#     <excluUseAr>
#      84.94
#     </excluUseAr>
#     <floor>
#      5
#     </floor>
#     <jibun>
#      96
#     </jibun>
#     <landCd>
#      1
#     </landCd>
#     <landLeaseholdGbn>
#      N
#     </landLeaseholdGbn>
#     <rgstDate>
#     </rgstDate>
#     <roadN
# ✅ 과천시 데이터 수집 완료 (108건)
# 📌 광명시 (41210) 데이터 요청 중...
# ✅ 광명시 응답 상태: 200
# 📊 광명시 응답 데이터 샘플:
# <?xml version="1.0" encoding="utf-8"?>
# <response>
#  <header>
#   <resultCode>
#    000
#   </resultCode>
#   <resultMsg>
#    OK
#   </resultMsg>
#  </header>
#  <body>
#   <items>
#    <item>
#     <aptDong>
#     </aptDong>
#     <aptNm>
#      철산센트럴푸르지오
#     </aptNm>
#     <aptSeq>
#      41210-3533
#     </aptSeq>
#     <bonbun>
#      0638
#     </bonbun>
#     <bubun>
#      0000
#     </bubun>
#     <buildYear>
#      2021
#     </buildYear>
#     <buyerGbn>
#      개인
#     </buyerGbn>
#     <cdealDay>
#     </cdealDay>
#     <cdealType>
#     </cdealType>
#     <dealAmount>
#      100,500
#     </dealAmount>
#     <dealDay>
#      19
#     </dealDay>
#     <dealMonth>
#      2
#     </dealMonth>
#     <dealYear>
#      2025
#     </dealYear>
#     <dealingGbn>
#      중개거래
#     </dealingGbn>
#     <estateAgentSggNm>
#      경기 광명시, 경기 용인시 처인구
#     </estateAgentSggNm>
#     <excluUseAr>
#      59.9897
#     </excluUseAr>
#     <floor>
#      8
#     </floor>
#     <jibun>
#      638
#     </jibun>
#     <landCd>
#      1
#     </landCd>
#     <landLeaseholdGbn>
#      N
#     </landLeaseholdGbn>
#     <rgstDate>
# ✅ 광명시 데이터 수집 완료 (182건)
# 📌 광주시 (41610) 데이터 요청 중...
# ✅ 광주시 응답 상태: 200
# 📊 광주시 응답 데이터 샘플:
# <?xml version="1.0" encoding="utf-8"?>
# <response>
#  <header>
#   <resultCode>
#    000
#   </resultCode>
#   <resultMsg>
#    OK
#   </resultMsg>
#  </header>
#  <body>
#   <items>
#    <item>
#     <aptDong>
#     </aptDong>
#     <aptNm>
#      도평리1차우림퓨전빌
#     </aptNm>
#     <aptSeq>
#      41610-1248
#     </aptSeq>
#     <bonbun>
#      0205
#     </bonbun>
#     <bubun>
#      0000
#     </bubun>
#     <buildYear>
#      2002
#     </buildYear>
#     <buyerGbn>
#      개인
#     </buyerGbn>
#     <cdealDay>
#     </cdealDay>
#     <cdealType>
#     </cdealType>
#     <dealAmount>
#      24,000
#     </dealAmount>
#     <dealDay>
#      28
#     </dealDay>
#     <dealMonth>
#      2
#     </dealMonth>
#     <dealYear>
#      2025
#     </dealYear>
#     <dealingGbn>
#      중개거래
#     </dealingGbn>
#     <estateAgentSggNm>
#      경기 광주시
#     </estateAgentSggNm>
#     <excluUseAr>
#      84.573
#     </excluUseAr>
#     <floor>
#      2
#     </floor>
#     <jibun>
#      205
#     </jibun>
#     <landCd>
#      1
#     </landCd>
#     <landLeaseholdGbn>
#      N
#     </landLeaseholdGbn>
#     <rgstDate>
#     </rgstDa
# ✅ 광주시 데이터 수집 완료 (167건)
# 📌 구리시 (41310) 데이터 요청 중...
# ✅ 구리시 응답 상태: 200
# 📊 구리시 응답 데이터 샘플:
# <?xml version="1.0" encoding="utf-8"?>
# <response>
#  <header>
#   <resultCode>
#    000
#   </resultCode>
#   <resultMsg>
#    OK
#   </resultMsg>
#  </header>
#  <body>
#   <items>
#    <item>
#     <aptDong>
#     </aptDong>
#     <aptNm>
#      한진
#     </aptNm>
#     <aptSeq>
#      41310-20
#     </aptSeq>
#     <bonbun>
#      0029
#     </bonbun>
#     <bubun>
#      0000
#     </bubun>
#     <buildYear>
#      2002
#     </buildYear>
#     <buyerGbn>
#      개인
#     </buyerGbn>
#     <cdealDay>
#     </cdealDay>
#     <cdealType>
#     </cdealType>
#     <dealAmount>
#      45,000
#     </dealAmount>
#     <dealDay>
#      14
#     </dealDay>
#     <dealMonth>
#      2
#     </dealMonth>
#     <dealYear>
#      2025
#     </dealYear>
#     <dealingGbn>
#      중개거래
#     </dealingGbn>
#     <estateAgentSggNm>
#      경기 구리시
#     </estateAgentSggNm>
#     <excluUseAr>
#      59.937
#     </excluUseAr>
#     <floor>
#      23
#     </floor>
#     <jibun>
#      29
#     </jibun>
#     <landCd>
#      1
#     </landCd>
#     <landLeaseholdGbn>
#      N
#     </landLeaseholdGbn>
#     <rgstDate>
#     </rgstDate>
#     <r
# ✅ 구리시 데이터 수집 완료 (87건)
# 📌 군포시 (41410) 데이터 요청 중...
# ✅ 군포시 응답 상태: 200
# 📊 군포시 응답 데이터 샘플:
# <?xml version="1.0" encoding="utf-8"?>
# <response>
#  <header>
#   <resultCode>
#    000
#   </resultCode>
#   <resultMsg>
#    OK
#   </resultMsg>
#  </header>
#  <body>
#   <items>
#    <item>
#     <aptDong>
#     </aptDong>
#     <aptNm>
#      대원칸타빌(104동,105동)
#     </aptNm>
#     <aptSeq>
#      41410-1309
#     </aptSeq>
#     <bonbun>
#      1022
#     </bonbun>
#     <bubun>
#      0001
#     </bubun>
#     <buildYear>
#      2009
#     </buildYear>
#     <buyerGbn>
#      개인
#     </buyerGbn>
#     <cdealDay>
#     </cdealDay>
#     <cdealType>
#     </cdealType>
#     <dealAmount>
#      46,500
#     </dealAmount>
#     <dealDay>
#      20
#     </dealDay>
#     <dealMonth>
#      2
#     </dealMonth>
#     <dealYear>
#      2025
#     </dealYear>
#     <dealingGbn>
#      중개거래
#     </dealingGbn>
#     <estateAgentSggNm>
#      경기 군포시
#     </estateAgentSggNm>
#     <excluUseAr>
#      84.85
#     </excluUseAr>
#     <floor>
#      2
#     </floor>
#     <jibun>
#      1022-1
#     </jibun>
#     <landCd>
#      1
#     </landCd>
#     <landLeaseholdGbn>
#      N
#     </landLeaseholdGbn>
#     <rgstDate>
#
# ✅ 군포시 데이터 수집 완료 (168건)
# 📌 김포시 (41570) 데이터 요청 중...
# ✅ 김포시 응답 상태: 200
# 📊 김포시 응답 데이터 샘플:
# <?xml version="1.0" encoding="utf-8"?>
# <response>
#  <header>
#   <resultCode>
#    000
#   </resultCode>
#   <resultMsg>
#    OK
#   </resultMsg>
#  </header>
#  <body>
#   <items>
#    <item>
#     <aptDong>
#     </aptDong>
#     <aptNm>
#      한강메트로자이2단지
#     </aptNm>
#     <aptSeq>
#      41570-1100
#     </aptSeq>
#     <bonbun>
#      1591
#     </bonbun>
#     <bubun>
#      0000
#     </bubun>
#     <buildYear>
#      2020
#     </buildYear>
#     <buyerGbn>
#      개인
#     </buyerGbn>
#     <cdealDay>
#     </cdealDay>
#     <cdealType>
#     </cdealType>
#     <dealAmount>
#      51,000
#     </dealAmount>
#     <dealDay>
#      18
#     </dealDay>
#     <dealMonth>
#      2
#     </dealMonth>
#     <dealYear>
#      2025
#     </dealYear>
#     <dealingGbn>
#      직거래
#     </dealingGbn>
#     <estateAgentSggNm>
#     </estateAgentSggNm>
#     <excluUseAr>
#      84.9402
#     </excluUseAr>
#     <floor>
#      21
#     </floor>
#     <jibun>
#      1591
#     </jibun>
#     <landCd>
#      1
#     </landCd>
#     <landLeaseholdGbn>
#      N
#     </landLeaseholdGbn>
#     <rgstDate>
#     </rgstDate>
#     <r
# ✅ 김포시 데이터 수집 완료 (353건)
# 📌 남양주시 (41360) 데이터 요청 중...
# ✅ 남양주시 응답 상태: 200
# 📊 남양주시 응답 데이터 샘플:
# <?xml version="1.0" encoding="utf-8"?>
# <response>
#  <header>
#   <resultCode>
#    000
#   </resultCode>
#   <resultMsg>
#    OK
#   </resultMsg>
#  </header>
#  <body>
#   <items>
#    <item>
#     <aptDong>
#     </aptDong>
#     <aptNm>
#      화도효성해링턴플레이스
#     </aptNm>
#     <aptSeq>
#      41360-3367
#     </aptSeq>
#     <bonbun>
#      1527
#     </bonbun>
#     <bubun>
#      0000
#     </bubun>
#     <buildYear>
#      2015
#     </buildYear>
#     <buyerGbn>
#      개인
#     </buyerGbn>
#     <cdealDay>
#     </cdealDay>
#     <cdealType>
#     </cdealType>
#     <dealAmount>
#      32,550
#     </dealAmount>
#     <dealDay>
#      16
#     </dealDay>
#     <dealMonth>
#      2
#     </dealMonth>
#     <dealYear>
#      2025
#     </dealYear>
#     <dealingGbn>
#      중개거래
#     </dealingGbn>
#     <estateAgentSggNm>
#      경기 남양주시
#     </estateAgentSggNm>
#     <excluUseAr>
#      84.9915
#     </excluUseAr>
#     <floor>
#      2
#     </floor>
#     <jibun>
#      1527
#     </jibun>
#     <landCd>
#      1
#     </landCd>
#     <landLeaseholdGbn>
#      N
#     </landLeaseholdGbn>
#     <rgstDate>
#     </rg
# ✅ 남양주시 데이터 수집 완료 (447건)
# 📌 동두천시 (41250) 데이터 요청 중...
# ✅ 동두천시 응답 상태: 200
# 📊 동두천시 응답 데이터 샘플:
# <?xml version="1.0" encoding="utf-8"?>
# <response>
#  <header>
#   <resultCode>
#    000
#   </resultCode>
#   <resultMsg>
#    OK
#   </resultMsg>
#  </header>
#  <body>
#   <items>
#    <item>
#     <aptDong>
#     </aptDong>
#     <aptNm>
#      지행현대1차아파트
#     </aptNm>
#     <aptSeq>
#      41250-15
#     </aptSeq>
#     <bonbun>
#      0282
#     </bonbun>
#     <bubun>
#      0005
#     </bubun>
#     <buildYear>
#      1999
#     </buildYear>
#     <buyerGbn>
#      개인
#     </buyerGbn>
#     <cdealDay>
#     </cdealDay>
#     <cdealType>
#     </cdealType>
#     <dealAmount>
#      12,000
#     </dealAmount>
#     <dealDay>
#      17
#     </dealDay>
#     <dealMonth>
#      2
#     </dealMonth>
#     <dealYear>
#      2025
#     </dealYear>
#     <dealingGbn>
#      직거래
#     </dealingGbn>
#     <estateAgentSggNm>
#     </estateAgentSggNm>
#     <excluUseAr>
#      59.84
#     </excluUseAr>
#     <floor>
#      1
#     </floor>
#     <jibun>
#      282-5
#     </jibun>
#     <landCd>
#      1
#     </landCd>
#     <landLeaseholdGbn>
#      N
#     </landLeaseholdGbn>
#     <rgstDate>
#     </rgstDate>
#     <roadNm
# ✅ 동두천시 데이터 수집 완료 (74건)
# 📌 부천시 (41190) 데이터 요청 중...
# ✅ 부천시 응답 상태: 200
# 📊 부천시 응답 데이터 샘플:
# <?xml version="1.0" encoding="utf-8"?>
# <response>
#  <header>
#   <resultCode>
#    000
#   </resultCode>
#   <resultMsg>
#    OK
#   </resultMsg>
#  </header>
#  <body>
#   <items/>
#   <numOfRows>
#    999
#   </numOfRows>
#   <pageNo>
#    1
#   </pageNo>
#   <totalCount>
#    0
#   </totalCount>
#  </body>
# </response>
#
# ⚠️ 부천시에 거래 데이터가 없습니다.
# 📌 성남시 분당구 (41135) 데이터 요청 중...
# ✅ 성남시 분당구 응답 상태: 200
# 📊 성남시 분당구 응답 데이터 샘플:
# <?xml version="1.0" encoding="utf-8"?>
# <response>
#  <header>
#   <resultCode>
#    000
#   </resultCode>
#   <resultMsg>
#    OK
#   </resultMsg>
#  </header>
#  <body>
#   <items>
#    <item>
#     <aptDong>
#     </aptDong>
#     <aptNm>
#      효자촌(임광)
#     </aptNm>
#     <aptSeq>
#      41135-110
#     </aptSeq>
#     <bonbun>
#      0292
#     </bonbun>
#     <bubun>
#      0000
#     </bubun>
#     <buildYear>
#      1992
#     </buildYear>
#     <buyerGbn>
#      개인
#     </buyerGbn>
#     <cdealDay>
#     </cdealDay>
#     <cdealType>
#     </cdealType>
#     <dealAmount>
#      79,000
#     </dealAmount>
#     <dealDay>
#      12
#     </dealDay>
#     <dealMonth>
#      2
#     </dealMonth>
#     <dealYear>
#      2025
#     </dealYear>
#     <dealingGbn>
#      중개거래
#     </dealingGbn>
#     <estateAgentSggNm>
#      경기 성남시 분당구
#     </estateAgentSggNm>
#     <excluUseAr>
#      59.73
#     </excluUseAr>
#     <floor>
#      5
#     </floor>
#     <jibun>
#      292
#     </jibun>
#     <landCd>
#      1
#     </landCd>
#     <landLeaseholdGbn>
#      N
#     </landLeaseholdGbn>
#     <rgstDate>
#     </rgstDat
# ✅ 성남시 분당구 데이터 수집 완료 (341건)
# 📌 성남시 수정구 (41131) 데이터 요청 중...
# ✅ 성남시 수정구 응답 상태: 200
# 📊 성남시 수정구 응답 데이터 샘플:
# <?xml version="1.0" encoding="utf-8"?>
# <response>
#  <header>
#   <resultCode>
#    000
#   </resultCode>
#   <resultMsg>
#    OK
#   </resultMsg>
#  </header>
#  <body>
#   <items>
#    <item>
#     <aptDong>
#     </aptDong>
#     <aptNm>
#      래미안위례
#     </aptNm>
#     <aptSeq>
#      41131-1491
#     </aptSeq>
#     <bonbun>
#      0528
#     </bonbun>
#     <bubun>
#      0000
#     </bubun>
#     <buildYear>
#      2015
#     </buildYear>
#     <buyerGbn>
#      개인
#     </buyerGbn>
#     <cdealDay>
#     </cdealDay>
#     <cdealType>
#     </cdealType>
#     <dealAmount>
#      178,000
#     </dealAmount>
#     <dealDay>
#      24
#     </dealDay>
#     <dealMonth>
#      2
#     </dealMonth>
#     <dealYear>
#      2025
#     </dealYear>
#     <dealingGbn>
#      중개거래
#     </dealingGbn>
#     <estateAgentSggNm>
#      경기 성남시 수정구, 서울 송파구
#     </estateAgentSggNm>
#     <excluUseAr>
#      101.19
#     </excluUseAr>
#     <floor>
#      16
#     </floor>
#     <jibun>
#      528
#     </jibun>
#     <landCd>
#      1
#     </landCd>
#     <landLeaseholdGbn>
#      N
#     </landLeaseholdGbn>
#     <rgstDate>
#
# ✅ 성남시 수정구 데이터 수집 완료 (77건)
# 📌 성남시 중원구 (41133) 데이터 요청 중...
# ✅ 성남시 중원구 응답 상태: 200
# 📊 성남시 중원구 응답 데이터 샘플:
# <?xml version="1.0" encoding="utf-8"?>
# <response>
#  <header>
#   <resultCode>
#    000
#   </resultCode>
#   <resultMsg>
#    OK
#   </resultMsg>
#  </header>
#  <body>
#   <items>
#    <item>
#     <aptDong>
#     </aptDong>
#     <aptNm>
#      삼익금광1차
#     </aptNm>
#     <aptSeq>
#      41133-27
#     </aptSeq>
#     <bonbun>
#      3950
#     </bonbun>
#     <bubun>
#      0000
#     </bubun>
#     <buildYear>
#      1991
#     </buildYear>
#     <buyerGbn>
#      개인
#     </buyerGbn>
#     <cdealDay>
#     </cdealDay>
#     <cdealType>
#     </cdealType>
#     <dealAmount>
#      30,000
#     </dealAmount>
#     <dealDay>
#      28
#     </dealDay>
#     <dealMonth>
#      2
#     </dealMonth>
#     <dealYear>
#      2025
#     </dealYear>
#     <dealingGbn>
#      중개거래
#     </dealingGbn>
#     <estateAgentSggNm>
#      경기 성남시 중원구
#     </estateAgentSggNm>
#     <excluUseAr>
#      34.05
#     </excluUseAr>
#     <floor>
#      3
#     </floor>
#     <jibun>
#      3950
#     </jibun>
#     <landCd>
#      1
#     </landCd>
#     <landLeaseholdGbn>
#      N
#     </landLeaseholdGbn>
#     <rgstDate>
#     </rgstDate
# ✅ 성남시 중원구 데이터 수집 완료 (109건)
# 📌 수원시 권선구 (41115) 데이터 요청 중...
# ✅ 수원시 권선구 응답 상태: 200
# 📊 수원시 권선구 응답 데이터 샘플:
# <?xml version="1.0" encoding="utf-8"?>
# <response>
#  <header>
#   <resultCode>
#    000
#   </resultCode>
#   <resultMsg>
#    OK
#   </resultMsg>
#  </header>
#  <body>
#   <items>
#    <item>
#     <aptDong>
#     </aptDong>
#     <aptNm>
#      매교역푸르지오SKVIEW
#     </aptNm>
#     <aptSeq>
#      41115-1905
#     </aptSeq>
#     <bonbun>
#      0300
#     </bonbun>
#     <bubun>
#      0000
#     </bubun>
#     <buildYear>
#      2023
#     </buildYear>
#     <buyerGbn>
#      개인
#     </buyerGbn>
#     <cdealDay>
#     </cdealDay>
#     <cdealType>
#     </cdealType>
#     <dealAmount>
#      75,000
#     </dealAmount>
#     <dealDay>
#      17
#     </dealDay>
#     <dealMonth>
#      2
#     </dealMonth>
#     <dealYear>
#      2025
#     </dealYear>
#     <dealingGbn>
#      중개거래
#     </dealingGbn>
#     <estateAgentSggNm>
#      경기 수원시 팔달구
#     </estateAgentSggNm>
#     <excluUseAr>
#      74.69
#     </excluUseAr>
#     <floor>
#      1
#     </floor>
#     <jibun>
#      300
#     </jibun>
#     <landCd>
#      1
#     </landCd>
#     <landLeaseholdGbn>
#      N
#     </landLeaseholdGbn>
#     <rgstDate>
#     </
# ✅ 수원시 권선구 데이터 수집 완료 (89건)
# 📌 수원시 영통구 (41117) 데이터 요청 중...
# ✅ 수원시 영통구 응답 상태: 200
# 📊 수원시 영통구 응답 데이터 샘플:
# <?xml version="1.0" encoding="utf-8"?>
# <response>
#  <header>
#   <resultCode>
#    000
#   </resultCode>
#   <resultMsg>
#    OK
#   </resultMsg>
#  </header>
#  <body>
#   <items>
#    <item>
#     <aptDong>
#     </aptDong>
#     <aptNm>
#      매탄위브하늘채
#     </aptNm>
#     <aptSeq>
#      41117-234
#     </aptSeq>
#     <bonbun>
#      1352
#     </bonbun>
#     <bubun>
#      0000
#     </bubun>
#     <buildYear>
#      2008
#     </buildYear>
#     <buyerGbn>
#      개인
#     </buyerGbn>
#     <cdealDay>
#     </cdealDay>
#     <cdealType>
#     </cdealType>
#     <dealAmount>
#      81,500
#     </dealAmount>
#     <dealDay>
#      27
#     </dealDay>
#     <dealMonth>
#      2
#     </dealMonth>
#     <dealYear>
#      2025
#     </dealYear>
#     <dealingGbn>
#      중개거래
#     </dealingGbn>
#     <estateAgentSggNm>
#      경기 수원시 영통구
#     </estateAgentSggNm>
#     <excluUseAr>
#      103.6419
#     </excluUseAr>
#     <floor>
#      5
#     </floor>
#     <jibun>
#      1352
#     </jibun>
#     <landCd>
#      1
#     </landCd>
#     <landLeaseholdGbn>
#      N
#     </landLeaseholdGbn>
#     <rgstDate>
#     </rgs
# ✅ 수원시 영통구 데이터 수집 완료 (335건)
# 📌 수원시 장안구 (41111) 데이터 요청 중...
# ✅ 수원시 장안구 응답 상태: 200
# 📊 수원시 장안구 응답 데이터 샘플:
# <?xml version="1.0" encoding="utf-8"?>
# <response>
#  <header>
#   <resultCode>
#    000
#   </resultCode>
#   <resultMsg>
#    OK
#   </resultMsg>
#  </header>
#  <body>
#   <items>
#    <item>
#     <aptDong>
#     </aptDong>
#     <aptNm>
#      한일타운쌍용
#     </aptNm>
#     <aptSeq>
#      41111-93
#     </aptSeq>
#     <bonbun>
#      0881
#     </bonbun>
#     <bubun>
#      0000
#     </bubun>
#     <buildYear>
#      1999
#     </buildYear>
#     <buyerGbn>
#      개인
#     </buyerGbn>
#     <cdealDay>
#     </cdealDay>
#     <cdealType>
#     </cdealType>
#     <dealAmount>
#      45,000
#     </dealAmount>
#     <dealDay>
#      19
#     </dealDay>
#     <dealMonth>
#      2
#     </dealMonth>
#     <dealYear>
#      2025
#     </dealYear>
#     <dealingGbn>
#      중개거래
#     </dealingGbn>
#     <estateAgentSggNm>
#      경기 수원시 장안구
#     </estateAgentSggNm>
#     <excluUseAr>
#      59.962
#     </excluUseAr>
#     <floor>
#      20
#     </floor>
#     <jibun>
#      881
#     </jibun>
#     <landCd>
#      1
#     </landCd>
#     <landLeaseholdGbn>
#      N
#     </landLeaseholdGbn>
#     <rgstDate>
#     </rgstDat
# ✅ 수원시 장안구 데이터 수집 완료 (172건)
# 📌 수원시 팔달구 (41113) 데이터 요청 중...
# ✅ 수원시 팔달구 응답 상태: 200
# 📊 수원시 팔달구 응답 데이터 샘플:
# <?xml version="1.0" encoding="utf-8"?>
# <response>
#  <header>
#   <resultCode>
#    000
#   </resultCode>
#   <resultMsg>
#    OK
#   </resultMsg>
#  </header>
#  <body>
#   <items>
#    <item>
#     <aptDong>
#     </aptDong>
#     <aptNm>
#      대원신동아
#     </aptNm>
#     <aptSeq>
#      41113-42
#     </aptSeq>
#     <bonbun>
#      1274
#     </bonbun>
#     <bubun>
#      0000
#     </bubun>
#     <buildYear>
#      1996
#     </buildYear>
#     <buyerGbn>
#      개인
#     </buyerGbn>
#     <cdealDay>
#     </cdealDay>
#     <cdealType>
#     </cdealType>
#     <dealAmount>
#      30,800
#     </dealAmount>
#     <dealDay>
#      26
#     </dealDay>
#     <dealMonth>
#      2
#     </dealMonth>
#     <dealYear>
#      2025
#     </dealYear>
#     <dealingGbn>
#      중개거래
#     </dealingGbn>
#     <estateAgentSggNm>
#      경기 수원시 권선구
#     </estateAgentSggNm>
#     <excluUseAr>
#      59.88
#     </excluUseAr>
#     <floor>
#      10
#     </floor>
#     <jibun>
#      1274
#     </jibun>
#     <landCd>
#      1
#     </landCd>
#     <landLeaseholdGbn>
#      N
#     </landLeaseholdGbn>
#     <rgstDate>
#     </rgstDate
# ✅ 수원시 팔달구 데이터 수집 완료 (233건)
# 📌 시흥시 (41390) 데이터 요청 중...
# ✅ 시흥시 응답 상태: 200
# 📊 시흥시 응답 데이터 샘플:
# <?xml version="1.0" encoding="utf-8"?>
# <response>
#  <header>
#   <resultCode>
#    000
#   </resultCode>
#   <resultMsg>
#    OK
#   </resultMsg>
#  </header>
#  <body>
#   <items>
#    <item>
#     <aptDong>
#     </aptDong>
#     <aptNm>
#      목감한신더휴센트럴파크
#     </aptNm>
#     <aptSeq>
#      41390-2336
#     </aptSeq>
#     <bonbun>
#      0669
#     </bonbun>
#     <bubun>
#      0000
#     </bubun>
#     <buildYear>
#      2017
#     </buildYear>
#     <buyerGbn>
#      개인
#     </buyerGbn>
#     <cdealDay>
#     </cdealDay>
#     <cdealType>
#     </cdealType>
#     <dealAmount>
#      49,800
#     </dealAmount>
#     <dealDay>
#      24
#     </dealDay>
#     <dealMonth>
#      2
#     </dealMonth>
#     <dealYear>
#      2025
#     </dealYear>
#     <dealingGbn>
#      중개거래
#     </dealingGbn>
#     <estateAgentSggNm>
#      경기 시흥시
#     </estateAgentSggNm>
#     <excluUseAr>
#      63.98
#     </excluUseAr>
#     <floor>
#      4
#     </floor>
#     <jibun>
#      669
#     </jibun>
#     <landCd>
#      1
#     </landCd>
#     <landLeaseholdGbn>
#      N
#     </landLeaseholdGbn>
#     <rgstDate>
#     </rgstDa
# ✅ 시흥시 데이터 수집 완료 (446건)
# 📌 안산시 단원구 (41273) 데이터 요청 중...
# ✅ 안산시 단원구 응답 상태: 200
# 📊 안산시 단원구 응답 데이터 샘플:
# <?xml version="1.0" encoding="utf-8"?>
# <response>
#  <header>
#   <resultCode>
#    000
#   </resultCode>
#   <resultMsg>
#    OK
#   </resultMsg>
#  </header>
#  <body>
#   <items>
#    <item>
#     <aptDong>
#     </aptDong>
#     <aptNm>
#      군자주공11
#     </aptNm>
#     <aptSeq>
#      41273-67
#     </aptSeq>
#     <bonbun>
#      1078
#     </bonbun>
#     <bubun>
#      0000
#     </bubun>
#     <buildYear>
#      1990
#     </buildYear>
#     <buyerGbn>
#      개인
#     </buyerGbn>
#     <cdealDay>
#     </cdealDay>
#     <cdealType>
#     </cdealType>
#     <dealAmount>
#      21,500
#     </dealAmount>
#     <dealDay>
#      22
#     </dealDay>
#     <dealMonth>
#      2
#     </dealMonth>
#     <dealYear>
#      2025
#     </dealYear>
#     <dealingGbn>
#      중개거래
#     </dealingGbn>
#     <estateAgentSggNm>
#      경기 안산시 단원구
#     </estateAgentSggNm>
#     <excluUseAr>
#      39.27
#     </excluUseAr>
#     <floor>
#      3
#     </floor>
#     <jibun>
#      1078
#     </jibun>
#     <landCd>
#      1
#     </landCd>
#     <landLeaseholdGbn>
#      N
#     </landLeaseholdGbn>
#     <rgstDate>
#     </rgstDate
# ✅ 안산시 단원구 데이터 수집 완료 (188건)
# 📌 안산시 상록구 (41271) 데이터 요청 중...
# ✅ 안산시 상록구 응답 상태: 200
# 📊 안산시 상록구 응답 데이터 샘플:
# <?xml version="1.0" encoding="utf-8"?>
# <response>
#  <header>
#   <resultCode>
#    000
#   </resultCode>
#   <resultMsg>
#    OK
#   </resultMsg>
#  </header>
#  <body>
#   <items>
#    <item>
#     <aptDong>
#     </aptDong>
#     <aptNm>
#      그랑시티자이2차
#     </aptNm>
#     <aptSeq>
#      41271-6006
#     </aptSeq>
#     <bonbun>
#      1639
#     </bonbun>
#     <bubun>
#      0000
#     </bubun>
#     <buildYear>
#      2020
#     </buildYear>
#     <buyerGbn>
#      개인
#     </buyerGbn>
#     <cdealDay>
#     </cdealDay>
#     <cdealType>
#     </cdealType>
#     <dealAmount>
#      66,000
#     </dealAmount>
#     <dealDay>
#      27
#     </dealDay>
#     <dealMonth>
#      2
#     </dealMonth>
#     <dealYear>
#      2025
#     </dealYear>
#     <dealingGbn>
#      중개거래
#     </dealingGbn>
#     <estateAgentSggNm>
#      경기 안산시 상록구
#     </estateAgentSggNm>
#     <excluUseAr>
#      95.1274
#     </excluUseAr>
#     <floor>
#      2
#     </floor>
#     <jibun>
#      1639
#     </jibun>
#     <landCd>
#      1
#     </landCd>
#     <landLeaseholdGbn>
#      N
#     </landLeaseholdGbn>
#     <rgstDate>
#     </rg
# ✅ 안산시 상록구 데이터 수집 완료 (89건)
# 📌 안성시 (41550) 데이터 요청 중...
# ✅ 안성시 응답 상태: 200
# 📊 안성시 응답 데이터 샘플:
# <?xml version="1.0" encoding="utf-8"?>
# <response>
#  <header>
#   <resultCode>
#    000
#   </resultCode>
#   <resultMsg>
#    OK
#   </resultMsg>
#  </header>
#  <body>
#   <items>
#    <item>
#     <aptDong>
#     </aptDong>
#     <aptNm>
#      주은청설
#     </aptNm>
#     <aptSeq>
#      41550-35
#     </aptSeq>
#     <bonbun>
#      0036
#     </bonbun>
#     <bubun>
#      0001
#     </bubun>
#     <buildYear>
#      2000
#     </buildYear>
#     <buyerGbn>
#      개인
#     </buyerGbn>
#     <cdealDay>
#     </cdealDay>
#     <cdealType>
#     </cdealType>
#     <dealAmount>
#      8,300
#     </dealAmount>
#     <dealDay>
#      14
#     </dealDay>
#     <dealMonth>
#      2
#     </dealMonth>
#     <dealYear>
#      2025
#     </dealYear>
#     <dealingGbn>
#      중개거래
#     </dealingGbn>
#     <estateAgentSggNm>
#      경기 안성시
#     </estateAgentSggNm>
#     <excluUseAr>
#      39.75
#     </excluUseAr>
#     <floor>
#      15
#     </floor>
#     <jibun>
#      36-1
#     </jibun>
#     <landCd>
#      1
#     </landCd>
#     <landLeaseholdGbn>
#      N
#     </landLeaseholdGbn>
#     <rgstDate>
#     </rgstDate>
#
# ✅ 안성시 데이터 수집 완료 (190건)
# 📌 안양시 동안구 (41173) 데이터 요청 중...
# ✅ 안양시 동안구 응답 상태: 200
# 📊 안양시 동안구 응답 데이터 샘플:
# <?xml version="1.0" encoding="utf-8"?>
# <response>
#  <header>
#   <resultCode>
#    000
#   </resultCode>
#   <resultMsg>
#    OK
#   </resultMsg>
#  </header>
#  <body>
#   <items>
#    <item>
#     <aptDong>
#     </aptDong>
#     <aptNm>
#      임광한마음1차
#     </aptNm>
#     <aptSeq>
#      41173-159
#     </aptSeq>
#     <bonbun>
#      0895
#     </bonbun>
#     <bubun>
#      0000
#     </bubun>
#     <buildYear>
#      1999
#     </buildYear>
#     <buyerGbn>
#      개인
#     </buyerGbn>
#     <cdealDay>
#     </cdealDay>
#     <cdealType>
#     </cdealType>
#     <dealAmount>
#      50,400
#     </dealAmount>
#     <dealDay>
#      19
#     </dealDay>
#     <dealMonth>
#      2
#     </dealMonth>
#     <dealYear>
#      2025
#     </dealYear>
#     <dealingGbn>
#      중개거래
#     </dealingGbn>
#     <estateAgentSggNm>
#      경기 안양시 동안구
#     </estateAgentSggNm>
#     <excluUseAr>
#      59.97
#     </excluUseAr>
#     <floor>
#      5
#     </floor>
#     <jibun>
#      895
#     </jibun>
#     <landCd>
#      1
#     </landCd>
#     <landLeaseholdGbn>
#      N
#     </landLeaseholdGbn>
#     <rgstDate>
#     </rgstDat
# ✅ 안양시 동안구 데이터 수집 완료 (323건)
# 📌 안양시 만안구 (41171) 데이터 요청 중...
# ✅ 안양시 만안구 응답 상태: 200
# 📊 안양시 만안구 응답 데이터 샘플:
# <?xml version="1.0" encoding="utf-8"?>
# <response>
#  <header>
#   <resultCode>
#    000
#   </resultCode>
#   <resultMsg>
#    OK
#   </resultMsg>
#  </header>
#  <body>
#   <items>
#    <item>
#     <aptDong>
#     </aptDong>
#     <aptNm>
#      진흥
#     </aptNm>
#     <aptSeq>
#      41171-54
#     </aptSeq>
#     <bonbun>
#      0908
#     </bonbun>
#     <bubun>
#      0004
#     </bubun>
#     <buildYear>
#      1987
#     </buildYear>
#     <buyerGbn>
#      개인
#     </buyerGbn>
#     <cdealDay>
#     </cdealDay>
#     <cdealType>
#     </cdealType>
#     <dealAmount>
#      36,300
#     </dealAmount>
#     <dealDay>
#      26
#     </dealDay>
#     <dealMonth>
#      2
#     </dealMonth>
#     <dealYear>
#      2025
#     </dealYear>
#     <dealingGbn>
#      중개거래
#     </dealingGbn>
#     <estateAgentSggNm>
#      경기 안양시 만안구
#     </estateAgentSggNm>
#     <excluUseAr>
#      75.48
#     </excluUseAr>
#     <floor>
#      6
#     </floor>
#     <jibun>
#      908-4
#     </jibun>
#     <landCd>
#      1
#     </landCd>
#     <landLeaseholdGbn>
#      N
#     </landLeaseholdGbn>
#     <rgstDate>
#     </rgstDate>
#
# ✅ 안양시 만안구 데이터 수집 완료 (134건)
# 📌 양주시 (41630) 데이터 요청 중...
# ✅ 양주시 응답 상태: 200
# 📊 양주시 응답 데이터 샘플:
# <?xml version="1.0" encoding="utf-8"?>
# <response>
#  <header>
#   <resultCode>
#    000
#   </resultCode>
#   <resultMsg>
#    OK
#   </resultMsg>
#  </header>
#  <body>
#   <items>
#    <item>
#     <aptDong>
#     </aptDong>
#     <aptNm>
#      하늘빛마을
#     </aptNm>
#     <aptSeq>
#      41630-510
#     </aptSeq>
#     <bonbun>
#      0583
#     </bonbun>
#     <bubun>
#      0000
#     </bubun>
#     <buildYear>
#      2007
#     </buildYear>
#     <buyerGbn>
#      개인
#     </buyerGbn>
#     <cdealDay>
#     </cdealDay>
#     <cdealType>
#     </cdealType>
#     <dealAmount>
#      23,000
#     </dealAmount>
#     <dealDay>
#      23
#     </dealDay>
#     <dealMonth>
#      2
#     </dealMonth>
#     <dealYear>
#      2025
#     </dealYear>
#     <dealingGbn>
#      중개거래
#     </dealingGbn>
#     <estateAgentSggNm>
#      경기 양주시
#     </estateAgentSggNm>
#     <excluUseAr>
#      75.98
#     </excluUseAr>
#     <floor>
#      4
#     </floor>
#     <jibun>
#      583
#     </jibun>
#     <landCd>
#      1
#     </landCd>
#     <landLeaseholdGbn>
#      N
#     </landLeaseholdGbn>
#     <rgstDate>
#     </rgstDate>
#
# ✅ 양주시 데이터 수집 완료 (207건)
# 📌 양평군 (41830) 데이터 요청 중...
# ✅ 양평군 응답 상태: 200
# 📊 양평군 응답 데이터 샘플:
# <?xml version="1.0" encoding="utf-8"?>
# <response>
#  <header>
#   <resultCode>
#    000
#   </resultCode>
#   <resultMsg>
#    OK
#   </resultMsg>
#  </header>
#  <body>
#   <items>
#    <item>
#     <aptDong>
#     </aptDong>
#     <aptNm>
#      그린맨션2
#     </aptNm>
#     <aptSeq>
#      41830-2
#     </aptSeq>
#     <bonbun>
#      0137
#     </bonbun>
#     <bubun>
#      0048
#     </bubun>
#     <buildYear>
#      1995
#     </buildYear>
#     <buyerGbn>
#      개인
#     </buyerGbn>
#     <cdealDay>
#     </cdealDay>
#     <cdealType>
#     </cdealType>
#     <dealAmount>
#      16,200
#     </dealAmount>
#     <dealDay>
#      24
#     </dealDay>
#     <dealMonth>
#      2
#     </dealMonth>
#     <dealYear>
#      2025
#     </dealYear>
#     <dealingGbn>
#      중개거래
#     </dealingGbn>
#     <estateAgentSggNm>
#      경기 양평군
#     </estateAgentSggNm>
#     <excluUseAr>
#      59.76
#     </excluUseAr>
#     <floor>
#      8
#     </floor>
#     <jibun>
#      137-48
#     </jibun>
#     <landCd>
#      1
#     </landCd>
#     <landLeaseholdGbn>
#      N
#     </landLeaseholdGbn>
#     <rgstDate>
#     </rgstDate>
#
# ✅ 양평군 데이터 수집 완료 (24건)
# 📌 여주시 (41670) 데이터 요청 중...
# ✅ 여주시 응답 상태: 200
# 📊 여주시 응답 데이터 샘플:
# <?xml version="1.0" encoding="utf-8"?>
# <response>
#  <header>
#   <resultCode>
#    000
#   </resultCode>
#   <resultMsg>
#    OK
#   </resultMsg>
#  </header>
#  <body>
#   <items>
#    <item>
#     <aptDong>
#     </aptDong>
#     <aptNm>
#      여주역센트레빌트리니체
#     </aptNm>
#     <aptSeq>
#      41670-571
#     </aptSeq>
#     <bonbun>
#      0673
#     </bonbun>
#     <bubun>
#      0000
#     </bubun>
#     <buildYear>
#      2024
#     </buildYear>
#     <buyerGbn>
#      개인
#     </buyerGbn>
#     <cdealDay>
#     </cdealDay>
#     <cdealType>
#     </cdealType>
#     <dealAmount>
#      38,560
#     </dealAmount>
#     <dealDay>
#      19
#     </dealDay>
#     <dealMonth>
#      2
#     </dealMonth>
#     <dealYear>
#      2025
#     </dealYear>
#     <dealingGbn>
#      중개거래
#     </dealingGbn>
#     <estateAgentSggNm>
#      경기 여주시
#     </estateAgentSggNm>
#     <excluUseAr>
#      76.6971
#     </excluUseAr>
#     <floor>
#      8
#     </floor>
#     <jibun>
#      673
#     </jibun>
#     <landCd>
#      1
#     </landCd>
#     <landLeaseholdGbn>
#      N
#     </landLeaseholdGbn>
#     <rgstDate>
#     </rgstD
# ✅ 여주시 데이터 수집 완료 (57건)
# 📌 연천군 (41800) 데이터 요청 중...
# ✅ 연천군 응답 상태: 200
# 📊 연천군 응답 데이터 샘플:
# <?xml version="1.0" encoding="utf-8"?>
# <response>
#  <header>
#   <resultCode>
#    000
#   </resultCode>
#   <resultMsg>
#    OK
#   </resultMsg>
#  </header>
#  <body>
#   <items>
#    <item>
#     <aptDong>
#     </aptDong>
#     <aptNm>
#      e편한세상연천웰스하임
#     </aptNm>
#     <aptSeq>
#      41800-184
#     </aptSeq>
#     <bonbun>
#      0860
#     </bonbun>
#     <bubun>
#      0000
#     </bubun>
#     <buildYear>
#      2023
#     </buildYear>
#     <buyerGbn>
#      개인
#     </buyerGbn>
#     <cdealDay>
#     </cdealDay>
#     <cdealType>
#     </cdealType>
#     <dealAmount>
#      32,800
#     </dealAmount>
#     <dealDay>
#      8
#     </dealDay>
#     <dealMonth>
#      2
#     </dealMonth>
#     <dealYear>
#      2025
#     </dealYear>
#     <dealingGbn>
#      중개거래
#     </dealingGbn>
#     <estateAgentSggNm>
#      경기 연천군
#     </estateAgentSggNm>
#     <excluUseAr>
#      84.9934
#     </excluUseAr>
#     <floor>
#      16
#     </floor>
#     <jibun>
#      860
#     </jibun>
#     <landCd>
#      1
#     </landCd>
#     <landLeaseholdGbn>
#      N
#     </landLeaseholdGbn>
#     <rgstDate>
#     </rgstD
# ✅ 연천군 데이터 수집 완료 (24건)
# 📌 오산시 (41370) 데이터 요청 중...
# ✅ 오산시 응답 상태: 200
# 📊 오산시 응답 데이터 샘플:
# <?xml version="1.0" encoding="utf-8"?>
# <response>
#  <header>
#   <resultCode>
#    000
#   </resultCode>
#   <resultMsg>
#    OK
#   </resultMsg>
#  </header>
#  <body>
#   <items>
#    <item>
#     <aptDong>
#     </aptDong>
#     <aptNm>
#      중흥S-클래스에듀파크
#     </aptNm>
#     <aptSeq>
#      41370-1008
#     </aptSeq>
#     <bonbun>
#      0824
#     </bonbun>
#     <bubun>
#      0000
#     </bubun>
#     <buildYear>
#      2024
#     </buildYear>
#     <buyerGbn>
#      개인
#     </buyerGbn>
#     <cdealDay>
#     </cdealDay>
#     <cdealType>
#     </cdealType>
#     <dealAmount>
#      33,500
#     </dealAmount>
#     <dealDay>
#      22
#     </dealDay>
#     <dealMonth>
#      2
#     </dealMonth>
#     <dealYear>
#      2025
#     </dealYear>
#     <dealingGbn>
#      중개거래
#     </dealingGbn>
#     <estateAgentSggNm>
#      경기 오산시
#     </estateAgentSggNm>
#     <excluUseAr>
#      59.9706
#     </excluUseAr>
#     <floor>
#      13
#     </floor>
#     <jibun>
#      824
#     </jibun>
#     <landCd>
#      1
#     </landCd>
#     <landLeaseholdGbn>
#      N
#     </landLeaseholdGbn>
#     <rgstDate>
#     </rgs
# ✅ 오산시 데이터 수집 완료 (180건)
# 📌 용인시 기흥구 (41463) 데이터 요청 중...
# ✅ 용인시 기흥구 응답 상태: 200
# 📊 용인시 기흥구 응답 데이터 샘플:
# <?xml version="1.0" encoding="utf-8"?>
# <response>
#  <header>
#   <resultCode>
#    000
#   </resultCode>
#   <resultMsg>
#    OK
#   </resultMsg>
#  </header>
#  <body>
#   <items>
#    <item>
#     <aptDong>
#     </aptDong>
#     <aptNm>
#      기흥역더샵
#     </aptNm>
#     <aptSeq>
#      41463-940
#     </aptSeq>
#     <bonbun>
#      0661
#     </bonbun>
#     <bubun>
#      0000
#     </bubun>
#     <buildYear>
#      2018
#     </buildYear>
#     <buyerGbn>
#      개인
#     </buyerGbn>
#     <cdealDay>
#     </cdealDay>
#     <cdealType>
#     </cdealType>
#     <dealAmount>
#      92,000
#     </dealAmount>
#     <dealDay>
#      28
#     </dealDay>
#     <dealMonth>
#      2
#     </dealMonth>
#     <dealYear>
#      2025
#     </dealYear>
#     <dealingGbn>
#      중개거래
#     </dealingGbn>
#     <estateAgentSggNm>
#      경기 용인시 기흥구
#     </estateAgentSggNm>
#     <excluUseAr>
#      94.8088
#     </excluUseAr>
#     <floor>
#      11
#     </floor>
#     <jibun>
#      661
#     </jibun>
#     <landCd>
#      1
#     </landCd>
#     <landLeaseholdGbn>
#      N
#     </landLeaseholdGbn>
#     <rgstDate>
#     </rgstDa
# ✅ 용인시 기흥구 데이터 수집 완료 (309건)
# 📌 용인시 수지구 (41465) 데이터 요청 중...
# ✅ 용인시 수지구 응답 상태: 200
# 📊 용인시 수지구 응답 데이터 샘플:
# <?xml version="1.0" encoding="utf-8"?>
# <response>
#  <header>
#   <resultCode>
#    000
#   </resultCode>
#   <resultMsg>
#    OK
#   </resultMsg>
#  </header>
#  <body>
#   <items>
#    <item>
#     <aptDong>
#     </aptDong>
#     <aptNm>
#      만현마을쌍용1차
#     </aptNm>
#     <aptSeq>
#      41465-104
#     </aptSeq>
#     <bonbun>
#      0850
#     </bonbun>
#     <bubun>
#      0000
#     </bubun>
#     <buildYear>
#      2001
#     </buildYear>
#     <buyerGbn>
#      개인
#     </buyerGbn>
#     <cdealDay>
#     </cdealDay>
#     <cdealType>
#     </cdealType>
#     <dealAmount>
#      60,700
#     </dealAmount>
#     <dealDay>
#      28
#     </dealDay>
#     <dealMonth>
#      2
#     </dealMonth>
#     <dealYear>
#      2025
#     </dealYear>
#     <dealingGbn>
#      중개거래
#     </dealingGbn>
#     <estateAgentSggNm>
#      경기 용인시 수지구
#     </estateAgentSggNm>
#     <excluUseAr>
#      84.8
#     </excluUseAr>
#     <floor>
#      3
#     </floor>
#     <jibun>
#      850
#     </jibun>
#     <landCd>
#      1
#     </landCd>
#     <landLeaseholdGbn>
#      N
#     </landLeaseholdGbn>
#     <rgstDate>
#     </rgstDat
# ✅ 용인시 수지구 데이터 수집 완료 (444건)
# 📌 용인시 처인구 (41461) 데이터 요청 중...
# ✅ 용인시 처인구 응답 상태: 200
# 📊 용인시 처인구 응답 데이터 샘플:
# <?xml version="1.0" encoding="utf-8"?>
# <response>
#  <header>
#   <resultCode>
#    000
#   </resultCode>
#   <resultMsg>
#    OK
#   </resultMsg>
#  </header>
#  <body>
#   <items>
#    <item>
#     <aptDong>
#     </aptDong>
#     <aptNm>
#      서희스타힐스포레스트
#     </aptNm>
#     <aptSeq>
#      41461-2823
#     </aptSeq>
#     <bonbun>
#      0233
#     </bonbun>
#     <bubun>
#      0000
#     </bubun>
#     <buildYear>
#      2023
#     </buildYear>
#     <buyerGbn>
#      개인
#     </buyerGbn>
#     <cdealDay>
#     </cdealDay>
#     <cdealType>
#     </cdealType>
#     <dealAmount>
#      49,000
#     </dealAmount>
#     <dealDay>
#      14
#     </dealDay>
#     <dealMonth>
#      2
#     </dealMonth>
#     <dealYear>
#      2025
#     </dealYear>
#     <dealingGbn>
#      중개거래
#     </dealingGbn>
#     <estateAgentSggNm>
#      경기 수원시 장안구
#     </estateAgentSggNm>
#     <excluUseAr>
#      84.4547
#     </excluUseAr>
#     <floor>
#      21
#     </floor>
#     <jibun>
#      233
#     </jibun>
#     <landCd>
#      1
#     </landCd>
#     <landLeaseholdGbn>
#      N
#     </landLeaseholdGbn>
#     <rgstDate>
#     </
# ✅ 용인시 처인구 데이터 수집 완료 (137건)
# 📌 의왕시 (41430) 데이터 요청 중...
# ✅ 의왕시 응답 상태: 200
# 📊 의왕시 응답 데이터 샘플:
# <?xml version="1.0" encoding="utf-8"?>
# <response>
#  <header>
#   <resultCode>
#    000
#   </resultCode>
#   <resultMsg>
#    OK
#   </resultMsg>
#  </header>
#  <body>
#   <items>
#    <item>
#     <aptDong>
#     </aptDong>
#     <aptNm>
#      두산위브호수마을2단지
#     </aptNm>
#     <aptSeq>
#      41430-816
#     </aptSeq>
#     <bonbun>
#      0643
#     </bonbun>
#     <bubun>
#      0000
#     </bubun>
#     <buildYear>
#      2009
#     </buildYear>
#     <buyerGbn>
#      개인
#     </buyerGbn>
#     <cdealDay>
#     </cdealDay>
#     <cdealType>
#     </cdealType>
#     <dealAmount>
#      69,000
#     </dealAmount>
#     <dealDay>
#      19
#     </dealDay>
#     <dealMonth>
#      2
#     </dealMonth>
#     <dealYear>
#      2025
#     </dealYear>
#     <dealingGbn>
#      중개거래
#     </dealingGbn>
#     <estateAgentSggNm>
#      경기 의왕시
#     </estateAgentSggNm>
#     <excluUseAr>
#      80.174
#     </excluUseAr>
#     <floor>
#      3
#     </floor>
#     <jibun>
#      643
#     </jibun>
#     <landCd>
#      1
#     </landCd>
#     <landLeaseholdGbn>
#      N
#     </landLeaseholdGbn>
#     <rgstDate>
#     </rgstDa
# ✅ 의왕시 데이터 수집 완료 (149건)
# 📌 의정부시 (41150) 데이터 요청 중...
# ✅ 의정부시 응답 상태: 200
# 📊 의정부시 응답 데이터 샘플:
# <?xml version="1.0" encoding="utf-8"?>
# <response>
#  <header>
#   <resultCode>
#    000
#   </resultCode>
#   <resultMsg>
#    OK
#   </resultMsg>
#  </header>
#  <body>
#   <items>
#    <item>
#     <aptDong>
#     </aptDong>
#     <aptNm>
#      성원
#     </aptNm>
#     <aptSeq>
#      41150-61
#     </aptSeq>
#     <bonbun>
#      0169
#     </bonbun>
#     <bubun>
#      0020
#     </bubun>
#     <buildYear>
#      1993
#     </buildYear>
#     <buyerGbn>
#      개인
#     </buyerGbn>
#     <cdealDay>
#     </cdealDay>
#     <cdealType>
#     </cdealType>
#     <dealAmount>
#      15,150
#     </dealAmount>
#     <dealDay>
#      27
#     </dealDay>
#     <dealMonth>
#      2
#     </dealMonth>
#     <dealYear>
#      2025
#     </dealYear>
#     <dealingGbn>
#      중개거래
#     </dealingGbn>
#     <estateAgentSggNm>
#      경기 의정부시
#     </estateAgentSggNm>
#     <excluUseAr>
#      59.44
#     </excluUseAr>
#     <floor>
#      10
#     </floor>
#     <jibun>
#      169-20
#     </jibun>
#     <landCd>
#      1
#     </landCd>
#     <landLeaseholdGbn>
#      N
#     </landLeaseholdGbn>
#     <rgstDate>
#     </rgstDate>
#
# ✅ 의정부시 데이터 수집 완료 (353건)
# 📌 이천시 (41500) 데이터 요청 중...
# ✅ 이천시 응답 상태: 200
# 📊 이천시 응답 데이터 샘플:
# <?xml version="1.0" encoding="utf-8"?>
# <response>
#  <header>
#   <resultCode>
#    000
#   </resultCode>
#   <resultMsg>
#    OK
#   </resultMsg>
#  </header>
#  <body>
#   <items>
#    <item>
#     <aptDong>
#     </aptDong>
#     <aptNm>
#      벽산블루밍
#     </aptNm>
#     <aptSeq>
#      41500-751
#     </aptSeq>
#     <bonbun>
#      0514
#     </bonbun>
#     <bubun>
#      0000
#     </bubun>
#     <buildYear>
#      2010
#     </buildYear>
#     <buyerGbn>
#      개인
#     </buyerGbn>
#     <cdealDay>
#     </cdealDay>
#     <cdealType>
#     </cdealType>
#     <dealAmount>
#      40,500
#     </dealAmount>
#     <dealDay>
#      22
#     </dealDay>
#     <dealMonth>
#      2
#     </dealMonth>
#     <dealYear>
#      2025
#     </dealYear>
#     <dealingGbn>
#      중개거래
#     </dealingGbn>
#     <estateAgentSggNm>
#      경기 이천시
#     </estateAgentSggNm>
#     <excluUseAr>
#      114.96
#     </excluUseAr>
#     <floor>
#      15
#     </floor>
#     <jibun>
#      514
#     </jibun>
#     <landCd>
#      1
#     </landCd>
#     <landLeaseholdGbn>
#      N
#     </landLeaseholdGbn>
#     <rgstDate>
#     </rgstDate>
#
# ✅ 이천시 데이터 수집 완료 (89건)
# 📌 파주시 (41480) 데이터 요청 중...
# ✅ 파주시 응답 상태: 200
# 📊 파주시 응답 데이터 샘플:
# <?xml version="1.0" encoding="utf-8"?>
# <response>
#  <header>
#   <resultCode>
#    000
#   </resultCode>
#   <resultMsg>
#    OK
#   </resultMsg>
#  </header>
#  <body>
#   <items>
#    <item>
#     <aptDong>
#     </aptDong>
#     <aptNm>
#      신안실크밸리1차(897-0)
#     </aptNm>
#     <aptSeq>
#      41480-595
#     </aptSeq>
#     <bonbun>
#      0897
#     </bonbun>
#     <bubun>
#      0000
#     </bubun>
#     <buildYear>
#      2009
#     </buildYear>
#     <buyerGbn>
#      개인
#     </buyerGbn>
#     <cdealDay>
#     </cdealDay>
#     <cdealType>
#     </cdealType>
#     <dealAmount>
#      23,900
#     </dealAmount>
#     <dealDay>
#      20
#     </dealDay>
#     <dealMonth>
#      2
#     </dealMonth>
#     <dealYear>
#      2025
#     </dealYear>
#     <dealingGbn>
#      중개거래
#     </dealingGbn>
#     <estateAgentSggNm>
#      경기 파주시
#     </estateAgentSggNm>
#     <excluUseAr>
#      59.912
#     </excluUseAr>
#     <floor>
#      3
#     </floor>
#     <jibun>
#      897
#     </jibun>
#     <landCd>
#      1
#     </landCd>
#     <landLeaseholdGbn>
#      N
#     </landLeaseholdGbn>
#     <rgstDate>
#     </rg
# ✅ 파주시 데이터 수집 완료 (298건)
# 📌 평택시 (41220) 데이터 요청 중...
# ✅ 평택시 응답 상태: 200
# 📊 평택시 응답 데이터 샘플:
# <?xml version="1.0" encoding="utf-8"?>
# <response>
#  <header>
#   <resultCode>
#    000
#   </resultCode>
#   <resultMsg>
#    OK
#   </resultMsg>
#  </header>
#  <body>
#   <items>
#    <item>
#     <aptDong>
#     </aptDong>
#     <aptNm>
#      힐스테이트평택3차(3-1블록)
#     </aptNm>
#     <aptSeq>
#      41220-3302
#     </aptSeq>
#     <bonbun>
#      0596
#     </bonbun>
#     <bubun>
#      0000
#     </bubun>
#     <buildYear>
#      2019
#     </buildYear>
#     <buyerGbn>
#      개인
#     </buyerGbn>
#     <cdealDay>
#     </cdealDay>
#     <cdealType>
#     </cdealType>
#     <dealAmount>
#      43,000
#     </dealAmount>
#     <dealDay>
#      24
#     </dealDay>
#     <dealMonth>
#      2
#     </dealMonth>
#     <dealYear>
#      2025
#     </dealYear>
#     <dealingGbn>
#      중개거래
#     </dealingGbn>
#     <estateAgentSggNm>
#      경기 평택시
#     </estateAgentSggNm>
#     <excluUseAr>
#      84.87
#     </excluUseAr>
#     <floor>
#      8
#     </floor>
#     <jibun>
#      596
#     </jibun>
#     <landCd>
#      1
#     </landCd>
#     <landLeaseholdGbn>
#      N
#     </landLeaseholdGbn>
#     <rgstDate>
#     </r
# ✅ 평택시 데이터 수집 완료 (434건)
# 📌 포천시 (41650) 데이터 요청 중...
# ✅ 포천시 응답 상태: 200
# 📊 포천시 응답 데이터 샘플:
# <?xml version="1.0" encoding="utf-8"?>
# <response>
#  <header>
#   <resultCode>
#    000
#   </resultCode>
#   <resultMsg>
#    OK
#   </resultMsg>
#  </header>
#  <body>
#   <items>
#    <item>
#     <aptDong>
#     </aptDong>
#     <aptNm>
#      포천극동2차스타클래스
#     </aptNm>
#     <aptSeq>
#      41650-520
#     </aptSeq>
#     <bonbun>
#      0698
#     </bonbun>
#     <bubun>
#      0000
#     </bubun>
#     <buildYear>
#      2008
#     </buildYear>
#     <buyerGbn>
#      개인
#     </buyerGbn>
#     <cdealDay>
#     </cdealDay>
#     <cdealType>
#     </cdealType>
#     <dealAmount>
#      21,500
#     </dealAmount>
#     <dealDay>
#      14
#     </dealDay>
#     <dealMonth>
#      2
#     </dealMonth>
#     <dealYear>
#      2025
#     </dealYear>
#     <dealingGbn>
#      중개거래
#     </dealingGbn>
#     <estateAgentSggNm>
#      경기 포천시
#     </estateAgentSggNm>
#     <excluUseAr>
#      84.9645
#     </excluUseAr>
#     <floor>
#      8
#     </floor>
#     <jibun>
#      698
#     </jibun>
#     <landCd>
#      1
#     </landCd>
#     <landLeaseholdGbn>
#      N
#     </landLeaseholdGbn>
#     <rgstDate>
#     </rgstD
# ✅ 포천시 데이터 수집 완료 (65건)
# 📌 하남시 (41450) 데이터 요청 중...
# ✅ 하남시 응답 상태: 200
# 📊 하남시 응답 데이터 샘플:
# <?xml version="1.0" encoding="utf-8"?>
# <response>
#  <header>
#   <resultCode>
#    000
#   </resultCode>
#   <resultMsg>
#    OK
#   </resultMsg>
#  </header>
#  <body>
#   <items>
#    <item>
#     <aptDong>
#     </aptDong>
#     <aptNm>
#      미사강변동원로얄듀크
#     </aptNm>
#     <aptSeq>
#      41450-318
#     </aptSeq>
#     <bonbun>
#      0477
#     </bonbun>
#     <bubun>
#      0000
#     </bubun>
#     <buildYear>
#      2016
#     </buildYear>
#     <buyerGbn>
#      개인
#     </buyerGbn>
#     <cdealDay>
#     </cdealDay>
#     <cdealType>
#     </cdealType>
#     <dealAmount>
#      93,500
#     </dealAmount>
#     <dealDay>
#      22
#     </dealDay>
#     <dealMonth>
#      2
#     </dealMonth>
#     <dealYear>
#      2025
#     </dealYear>
#     <dealingGbn>
#      중개거래
#     </dealingGbn>
#     <estateAgentSggNm>
#      경기 하남시
#     </estateAgentSggNm>
#     <excluUseAr>
#      84.3852
#     </excluUseAr>
#     <floor>
#      16
#     </floor>
#     <jibun>
#      477
#     </jibun>
#     <landCd>
#      1
#     </landCd>
#     <landLeaseholdGbn>
#      N
#     </landLeaseholdGbn>
#     <rgstDate>
#     </rgstD
# ✅ 하남시 데이터 수집 완료 (251건)
# 📌 화성시 (41590) 데이터 요청 중...
# ✅ 화성시 응답 상태: 200
# 📊 화성시 응답 데이터 샘플:
# <?xml version="1.0" encoding="utf-8"?>
# <response>
#  <header>
#   <resultCode>
#    000
#   </resultCode>
#   <resultMsg>
#    OK
#   </resultMsg>
#  </header>
#  <body>
#   <items>
#    <item>
#     <aptDong>
#     </aptDong>
#     <aptNm>
#      푸른마을모아미래도
#     </aptNm>
#     <aptSeq>
#      41590-1026
#     </aptSeq>
#     <bonbun>
#      1151
#     </bonbun>
#     <bubun>
#      0000
#     </bubun>
#     <buildYear>
#      2008
#     </buildYear>
#     <buyerGbn>
#      개인
#     </buyerGbn>
#     <cdealDay>
#     </cdealDay>
#     <cdealType>
#     </cdealType>
#     <dealAmount>
#      39,700
#     </dealAmount>
#     <dealDay>
#      28
#     </dealDay>
#     <dealMonth>
#      2
#     </dealMonth>
#     <dealYear>
#      2025
#     </dealYear>
#     <dealingGbn>
#      중개거래
#     </dealingGbn>
#     <estateAgentSggNm>
#      경기 화성시
#     </estateAgentSggNm>
#     <excluUseAr>
#      59.039
#     </excluUseAr>
#     <floor>
#      12
#     </floor>
#     <jibun>
#      1151
#     </jibun>
#     <landCd>
#      1
#     </landCd>
#     <landLeaseholdGbn>
#      N
#     </landLeaseholdGbn>
#     <rgstDate>
#     </rgstD
# ✅ 화성시 데이터 수집 완료 (700건)
# 📦 데이터 수집 완료

# %%
import pandas as pd
import xml.etree.ElementTree as ET

df_gg_real_estate_data = pd.DataFrame()

for gu, items in gg_real_estate_data.items():
    for item in items:
        # XML 데이터를 파싱하여 Element 객체로 변환
        xml_data = str(item)

        # XML 파싱
        root = ET.fromstring(xml_data)

        # 각 항목을 딕셔너리 형태로 추출하여 리스트에 저장
        data = {
            'aptDong': root.find('aptDong').text if root.find('aptDong') is not None else '',
            'aptNm': root.find('aptNm').text if root.find('aptNm') is not None else '',
            'aptSeq': root.find('aptSeq').text if root.find('aptSeq') is not None else '',
            'bonbun': root.find('bonbun').text if root.find('bonbun') is not None else '',
            'bubun': root.find('bubun').text if root.find('bubun') is not None else '',
            'buildYear': root.find('buildYear').text if root.find('buildYear') is not None else '',
            'buyerGbn': root.find('buyerGbn').text if root.find('buyerGbn') is not None else '',
            'cdealDay': root.find('cdealDay').text if root.find('cdealDay') is not None else '',
            'cdealType': root.find('cdealType').text if root.find('cdealType') is not None else '',
            'dealAmount': root.find('dealAmount').text if root.find('dealAmount') is not None else '',
            'dealDay': root.find('dealDay').text if root.find('dealDay') is not None else '',
            'dealMonth': root.find('dealMonth').text if root.find('dealMonth') is not None else '',
            'dealYear': root.find('dealYear').text if root.find('dealYear') is not None else '',
            'dealingGbn': root.find('dealingGbn').text if root.find('dealingGbn') is not None else '',
            'estateAgentSggNm': root.find('estateAgentSggNm').text if root.find('estateAgentSggNm') is not None else '',
            'excluUseAr': root.find('excluUseAr').text if root.find('excluUseAr') is not None else '',
            'floor': root.find('floor').text if root.find('floor') is not None else '',
            'jibun': root.find('jibun').text if root.find('jibun') is not None else '',
            'landCd': root.find('landCd').text if root.find('landCd') is not None else '',
            'landLeaseholdGbn': root.find('landLeaseholdGbn').text if root.find('landLeaseholdGbn') is not None else '',
            'rgstDate': root.find('rgstDate').text if root.find('rgstDate') is not None else '',
            'roadNm': root.find('roadNm').text if root.find('roadNm') is not None else '',
            'roadNmBonbun': root.find('roadNmBonbun').text if root.find('roadNmBonbun') is not None else '',
            'roadNmBubun': root.find('roadNmBubun').text if root.find('roadNmBubun') is not None else '',
            'roadNmCd': root.find('roadNmCd').text if root.find('roadNmCd') is not None else '',
            'roadNmSeq': root.find('roadNmSeq').text if root.find('roadNmSeq') is not None else '',
            'roadNmSggCd': root.find('roadNmSggCd').text if root.find('roadNmSggCd') is not None else '',
            'roadNmbCd': root.find('roadNmbCd').text if root.find('roadNmbCd') is not None else '',
            'sggCd': root.find('sggCd').text if root.find('sggCd') is not None else '',
            'slerGbn': root.find('slerGbn').text if root.find('slerGbn') is not None else '',
            'umdCd': root.find('umdCd').text if root.find('umdCd') is not None else '',
            'umdNm': root.find('umdNm').text if root.find('umdNm') is not None else ''
        }

        # 데이터프레임으로 변환
        df = pd.DataFrame([data])

        # 기존 데이터프레임에 합침
        df_gg_real_estate_data = pd.concat([df_gg_real_estate_data, df], ignore_index=True)

# 결과 출력
df_gg_real_estate_data
# Out:
#      aptDong         aptNm      aptSeq bonbun bubun buildYear buyerGbn  \
# 0                  청평삼성쉐르빌   41820-334   0837  0000      2012       개인
# 1              가평센트럴파크더스카이   41820-508   0457  0005      2022       개인
# 2                  이안지안스청평   41820-436   0657  0001      2018       개인
# 3                   에이원파란채   41820-275   0771  0001      2007       개인
# 4        102            썬힐   41820-281   0402  0001      2008       개인
# ...      ...           ...         ...    ...   ...       ...      ...
# 8698          시범다은마을우남퍼스트빌   41590-966   0079  0000      2007       개인
# 8699          시범한빛마을삼부르네상스   41590-968   0083  0000      2007       개인
# 8700           한화 포레나 동탄호수  41590-2036   0921  0000      2020       개인
# 8701               신영통현대4차    41590-26   0870  0000      2002       개인
# 8702            구봉마을우남퍼스트빌    41590-63   0860  0000      2004       개인
#
#      cdealDay cdealType dealAmount  ... roadNmBonbun roadNmBubun roadNmCd  \
# 0                           26,000  ...        00054       00000  3216002
# 1                           34,800  ...        00011       00000  3216017
# 2                           21,000  ...        00020       00000  3216005
# 3                           16,000  ...        00223       00000  3000142
# 4                           18,000  ...        00063       00000  3216052
# ...       ...       ...        ...  ...          ...         ...      ...
# 8698                        69,500  ...        00171       00000  3210027
# 8699                        61,700  ...        00207       00000  3210169
# 8700                        71,800  ...        00011       00000  4852363
# 8701                        42,700  ...        00020       00000  4430968
# 8702                        46,000  ...        00023       00000  3210050
#
#      roadNmSeq roadNmSggCd roadNmbCd  sggCd slerGbn  umdCd    umdNm
# 0           01       41820         0  41820      개인  32521  청평면 청평리
# 1           00       41820         0  41820      개인  25021  가평읍 읍내리
# 2           00       41820            41820      개인  32521  청평면 청평리
# 3           01       41820         0  41820      개인  25021  가평읍 읍내리
# 4           01       41820         0  41820      개인  25022  가평읍 대곡리
# ...        ...         ...       ...    ...     ...    ...      ...
# 8698        01       41590         0  41590      개인  12700      반송동
# 8699        01       41590         0  41590      개인  12700      반송동
# 8700        00       41590         0  41590      개인  13600      장지동
# 8701        01       41590         0  41590      개인  12000      반월동
# 8702        00       41590         0  41590      개인  11700      병점동
#
# [8703 rows x 32 columns]

# %%
real_estate_schema = {
    "sggCd": "법정동시군구코드",
    "umdCd": "법정동읍면동코드",
    "landCd": "법정동지번코드",
    "bonbun": "법정동본번코드",
    "bubun": "법정동부번코드",
    "roadNm": "도로명",
    "roadNmSggCd": "도로명시군구코드",
    "roadNmCd": "도로명코드",
    "roadNmSeq": "도로명일련번호코드",
    "roadNmbCd": "도로명지상지하코드",
    "roadNmBonbun": "도로명건물본번호코드",
    "roadNmBubun": "도로명건물부번호코드",
    "umdNm": "법정동",
    "aptNm": "아파트명",
    "jibun": "지번",
    "excluUseAr": "전용면적",
    "dealYear": "계약년도",
    "dealMonth": "계약월",
    "dealDay": "계약일",
    "dealAmount": "거래금액(만원)",
    "floor": "층",
    "buildYear": "건축년도",
    "aptSeq": "단지 일련번호",
    "cdealType": "해제여부",
    "cdealDay": "해제사유발생일",
    "dealingGbn": "거래유형(중개 및 직거래 여부)",
    "estateAgentSggNm": "중개사소재지(시군구 단위)",
    "rgstDate": "등기일자",
    "aptDong": "아파트 동명",
    "slerGbn": "거래주체정보_매도자(개인/법인/공공기관/기타)",
    "buyerGbn": "거래주체정보_매수자(개인/법인/공공기관/기타)",
    "landLeaseholdGbn": "토지임대부 아파트 여부"
}

# %%
df_gg_real_estate_data.rename(columns=real_estate_schema, inplace=True)
df_gg_real_estate_data.head()
# Out:
#   아파트 동명         아파트명    단지 일련번호 법정동본번코드 법정동부번코드  건축년도  \
# 0             청평삼성쉐르빌  41820-334    0837    0000  2012
# 1         가평센트럴파크더스카이  41820-508    0457    0005  2022
# 2             이안지안스청평  41820-436    0657    0001  2018
# 3              에이원파란채  41820-275    0771    0001  2007
# 4    102           썬힐  41820-281    0402    0001  2008
#
#   거래주체정보_매수자(개인/법인/공공기관/기타) 해제사유발생일 해제여부 거래금액(만원)  ... 도로명건물본번호코드 도로명건물부번호코드  \
# 0                        개인                26,000  ...      00054      00000
# 1                        개인                34,800  ...      00011      00000
# 2                        개인                21,000  ...      00020      00000
# 3                        개인                16,000  ...      00223      00000
# 4                        개인                18,000  ...      00063      00000
#
#      도로명코드 도로명일련번호코드 도로명시군구코드 도로명지상지하코드 법정동시군구코드 거래주체정보_매도자(개인/법인/공공기관/기타)  \
# 0  3216002        01    41820         0    41820                        개인
# 1  3216017        00    41820         0    41820                        개인
# 2  3216005        00    41820              41820                        개인
# 3  3000142        01    41820         0    41820                        개인
# 4  3216052        01    41820         0    41820                        개인
#
#   법정동읍면동코드      법정동
# 0    32521  청평면 청평리
# 1    25021  가평읍 읍내리
# 2    32521  청평면 청평리
# 3    25021  가평읍 읍내리
# 4    25022  가평읍 대곡리
#
# [5 rows x 32 columns]

# %%
# 거래금액 칼럼 데이터타입 변환환
df_gg_real_estate_data['거래금액(만원)'] = df_gg_real_estate_data['거래금액(만원)'].str.replace(",", "").astype(int)

# %%
# 거래금액을 평균 값으로 그룹화
grouped_gyeonggi_2020 = df_gg_real_estate_data.groupby(["법정동"], as_index=False).agg({"거래금액(만원)": "mean"}).rename(columns={"거래금액(만원)": "거래금액_2020"}) 
grouped_gyeonggi_2020
# Out:
#          법정동     거래금액_2020
# 0    가남읍 신해리   9191.666667
# 1    가남읍 심석리   7900.000000
# 2        가능동  29177.272727
# 3        가사동  22255.555556
# 4        가수동  14325.000000
# ..       ...           ...
# 497  화도읍 창현리  27411.290323
# 498      화서동  47325.617284
# 499      화정동  37906.590909
# 500      회덕동  24025.000000
# 501      회정동  18223.333333
#
# [502 rows x 2 columns]

# %%
grouped_gyeonggi_2021 = df_gg_real_estate_data.groupby(["법정동"], as_index=False).agg({"거래금액(만원)": "mean"}).rename(columns={"거래금액(만원)": "거래금액_2021"}) 
grouped_gyeonggi_2021
# Out:
#          법정동     거래금액_2021
# 0    가남읍 신해리   8537.500000
# 1    가남읍 심석리   8733.333333
# 2        가능동  41960.000000
# 3        가사동  35000.000000
# 4        가수동  26987.500000
# ..       ...           ...
# 464  화도읍 창현리  30125.000000
# 465      화서동  56662.500000
# 466      화정동  54661.538462
# 467      회덕동  30750.000000
# 468      회정동  24450.000000
#
# [469 rows x 2 columns]

# %%
grouped_gyeonggi_2022 = df_gg_real_estate_data.groupby(["법정동"], as_index=False).agg({"거래금액(만원)": "mean"}).rename(columns={"거래금액(만원)": "거래금액_2022"}) 
grouped_gyeonggi_2022
# Out:
#          법정동     거래금액_2022
# 0    가남읍 신해리  11306.250000
# 1    가남읍 심석리   7556.500000
# 2    가남읍 태평리   9900.000000
# 3        가능동  22000.000000
# 4        가사동  30533.333333
# ..       ...           ...
# 427  화도읍 묵현리  29842.857143
# 428  화도읍 월산리  41000.000000
# 429  화도읍 창현리  21300.000000
# 430      화서동  41133.333333
# 431      화정동  44742.857143
#
# [432 rows x 2 columns]

# %%
grouped_gyeonggi_2023 = df_gg_real_estate_data.groupby(["법정동"], as_index=False).agg({"거래금액(만원)": "mean"}).rename(columns={"거래금액(만원)": "거래금액_2023"}) 
grouped_gyeonggi_2023
# Out:
#          법정동     거래금액_2023
# 0    가남읍 신해리  15425.000000
# 1    가남읍 심석리   8800.000000
# 2        가능동  29416.666667
# 3        가사동  37000.000000
# 4        가수동  25725.000000
# ..       ...           ...
# 480  화도읍 창현리  33087.500000
# 481      화서동  44100.000000
# 482      화정동  41470.833333
# 483      회덕동  26800.000000
# 484      회정동  31355.000000
#
# [485 rows x 2 columns]

# %%
grouped_gyeonggi_2024 = df_gg_real_estate_data.groupby(["법정동"], as_index=False).agg({"거래금액(만원)": "mean"}).rename(columns={"거래금액(만원)": "거래금액_2024"}) 
grouped_gyeonggi_2024
# Out:
#          법정동     거래금액_2024
# 0    가남읍 신해리   6400.000000
# 1        가능동  30773.333333
# 2        가사동  24950.000000
# 3        가수동  22566.666667
# 4        가재동  23500.000000
# ..       ...           ...
# 467  화도읍 묵현리  27400.000000
# 468  화도읍 창현리  24900.000000
# 469      화서동  49845.652174
# 470      화정동  40764.583333
# 471      회정동  24300.000000
#
# [472 rows x 2 columns]

# %%
grouped_gyeonggi_2025 = df_gg_real_estate_data.groupby(["법정동"], as_index=False).agg({"거래금액(만원)": "mean"}).rename(columns={"거래금액(만원)": "거래금액_2025"}) 
grouped_gyeonggi_2025
# Out:
#          법정동     거래금액_2025
# 0    가남읍 신해리  12164.285714
# 1    가남읍 심석리   7500.000000
# 2        가능동  33420.000000
# 3        가사동  26090.000000
# 4        가수동  27558.333333
# ..       ...           ...
# 492  화도읍 차산리  35071.428571
# 493  화도읍 창현리  28290.909091
# 494      화서동  49650.000000
# 495      화정동  44189.436620
# 496      회정동  43000.000000
#
# [497 rows x 2 columns]

# %%
gyeonggi = pd.merge(grouped_gyeonggi_2020, grouped_gyeonggi_2021, on='법정동', how='outer')
gyeonggi = pd.merge(gyeonggi, grouped_gyeonggi_2022, on='법정동', how='outer')  
gyeonggi = pd.merge(gyeonggi, grouped_gyeonggi_2023, on='법정동', how='outer')
gyeonggi = pd.merge(gyeonggi, grouped_gyeonggi_2024, on='법정동', how='outer')
gyeonggi = pd.merge(gyeonggi, grouped_gyeonggi_2025, on='법정동', how='outer')
gyeonggi
# Out:
#          법정동     거래금액_2020     거래금액_2021     거래금액_2022     거래금액_2023  \
# 0    가남읍 신해리   9191.666667   8537.500000  11306.250000  15425.000000
# 1    가남읍 심석리   7900.000000   8733.333333   7556.500000   8800.000000
# 2    가남읍 태평리           NaN           NaN   9900.000000           NaN
# 3        가능동  29177.272727  41960.000000  22000.000000  29416.666667
# 4        가사동  22255.555556  35000.000000  30533.333333  37000.000000
# ..       ...           ...           ...           ...           ...
# 553  화도읍 창현리  27411.290323  30125.000000  21300.000000  33087.500000
# 554      화서동  47325.617284  56662.500000  41133.333333  44100.000000
# 555      화정동  37906.590909  54661.538462  44742.857143  41470.833333
# 556      회덕동  24025.000000  30750.000000           NaN  26800.000000
# 557      회정동  18223.333333  24450.000000           NaN  31355.000000
#
#         거래금액_2024     거래금액_2025
# 0     6400.000000  12164.285714
# 1             NaN   7500.000000
# 2             NaN           NaN
# 3    30773.333333  33420.000000
# 4    24950.000000  26090.000000
# ..            ...           ...
# 553  24900.000000  28290.909091
# 554  49845.652174  49650.000000
# 555  40764.583333  44189.436620
# 556           NaN           NaN
# 557  24300.000000  43000.000000
#
# [558 rows x 7 columns]
