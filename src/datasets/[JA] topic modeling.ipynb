# %% [markdown]
# # Topic modeling

# %% [markdown]
# ## 일단 기사 하나로 해봄

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# %%
import pandas as pd
file_path = '/Users/JooAnLee/mid_project/src/datasets/수도권_아파트_청약_뉴스_크롤링.csv'
df = pd.read_csv(file_path)
df.head()
# Out:
#                                       title  \
# 0  “7인 가구에 무주택 15년 이상”…새해 첫 만점통장 ‘이곳’서 나왔다
# 1           올해 첫 청약 통장 만점 나온 단지는…서울 아니고 이곳
# 2   "지금 아니면 내집마련 못한다?"...새해 첫 84점 만점통장 나왔다
# 3               강달러 간다는데 환율 더 오르나 [3분 브리프]
# 4  [1월 1주 분양동향] '검단신도시파밀리에엘리프' 등 5911가구 분양
#
#                                              content  \
# 0  의왕 월암지구 대방 디에트르 레이크파크 조감도. [사진 출처 = 대방건설]경기도 의...
# 1  '의왕 디에트르 레이크파크'서 84점 나와[서울경제]의왕 월암 디에트르 레이크파크 ...
# 2  아파트 견본주택 전경. 사진=연합뉴스[파이낸셜뉴스] 무적통장으로 불리는 84점 만점...
# 3  [한 눈에 읽기]①금값 내년에도 고공행진 전망②1년새 121% 상승한 비트코인③머스...
# 4  일반분양 기준으론 5014가구⋯새해 맞아 견본주택 개관은 전무푸른 뱀의 해인 새해 ...
#
#                                                  url              apartment
# 0  https://n.news.naver.com/mnews/article/009/000...  의왕 월암지구 대방 디에트르 레이크파크
# 1  https://n.news.naver.com/mnews/article/011/000...  의왕 월암지구 대방 디에트르 레이크파크
# 2  https://n.news.naver.com/mnews/article/014/000...  의왕 월암지구 대방 디에트르 레이크파크
# 3  https://n.news.naver.com/mnews/article/277/000...  의왕 월암지구 대방 디에트르 레이크파크
# 4  https://n.news.naver.com/mnews/article/031/000...  의왕 월암지구 대방 디에트르 레이크파크

# %%
print("Content:\n", df.loc[0, 'content'])
print("\nURL:\n", df.loc[0, 'url'])
# Out:
# Content:
#  의왕 월암지구 대방 디에트르 레이크파크 조감도. [사진 출처 = 대방건설]경기도 의왕시에서 분양된 단지에서 올해 첫 청약통장 만점 당첨자가 나왔다.만점인 84점을 받으려면 7인 가구 이상으로 무주택 기간 15년 이상을 유지해야 한다.13일 청약홈에 따르면 지난 8일 당첨자를 발표한 ‘의왕 월암지구 대방 디에트르 레이크파크’에서 84점 만점 통장이 나왔다.만점 통장은 전용 84㎡A 기타 지역에서 나왔다. 최저 47점, 최고 84점을 기록했다.이 단지는 앞서 진행된 1·2순위 청약에서 386가구 공급(특별공급 제외)에 1625명이 신청했다.분양가 상한제가 적용돼 주변 시세보다 공급가격이 낮게 책정된 점이 수요자들의 관심을 끌었다.단지 분양가는 전용 75㎡ 기준 5억4000만원대, 전용 84㎡ 기준 6억1000만원대부터 시작된다.국토교통부 실거래가 공개시스템에 따르면 인근 위치한 ‘의왕역 푸르지오 라포레’의 전용 84㎡D타입은 지난해 7월 7억5000만원에 거래됐다.한편 지난해에는 총 7개 단지에서 만점 통장이 나왔다. 지역별로 보면 서울 4개, 경기 2개, 전북 1개 등이다.서울에서는 ‘래미안 원베일리’, ‘래미안 원펜타스’, ‘디에이치 대치 에델루이’ 등 분상제가 적용돼 분양가가 시세보다 저렴하게 나왔던 강남3구 아파트에 집중됐다.올해는 이른바 ‘로또 청약’으로 불리는 분상제 적용 물량이 줄어들 것으로 예상되면서 고가점 통장 경쟁도 더 치열할 것으로 예상된다.
#
# URL:
#  https://n.news.naver.com/mnews/article/009/0005428089?sid=101

# %%
train_article = """
의왕 월암지구 대방 디에트르 레이크파크 조감도. [사진 출처 = 대방건설]경기도 의왕시에서 분양된 단지에서 올해 첫 청약통장 만점 당첨자가 나왔다. 만점인 84점을 받으려면 7인 가구 이상으로 무주택 기간 15년 이상을 유지해야 한다. 13일 청약홈에 따르면 지난 8일 당첨자를 발표한 ‘의왕 월암지구 대방 디에트르 레이크파크’에서 84점 만점 통장이 나왔다. 만점 통장은 전용 84㎡A 기타 지역에서 나왔다. 최저 47점, 최고 84점을 기록했다. 이 단지는 앞서 진행된 1·2순위 청약에서 386가구 공급(특별공급 제외)에 1625명이 신청했다. 분양가 상한제가 적용돼 주변 시세보다 공급가격이 낮게 책정된 점이 수요자들의 관심을 끌었다. 단지 분양가는 전용 75㎡ 기준 5억4000만원대, 전용 84㎡ 기준 6억1000만원대부터 시작된다. 국토교통부 실거래가 공개시스템에 따르면 인근 위치한 ‘의왕역 푸르지오 라포레’의 전용 84㎡D타입은 지난해 7월 7억5000만원에 거래됐다. 한편 지난해에는 총 7개 단지에서 만점 통장이 나왔다. 지역별로 보면 서울 4개, 경기 2개, 전북 1개 등이다. 서울에서는 ‘래미안 원베일리’, ‘래미안 원펜타스’, ‘디에이치 대치 에델루이’ 등 분상제가 적용돼 분양가가 시세보다 저렴하게 나왔던 강남3구 아파트에 집중됐다. 올해는 이른바 ‘로또 청약’으로 불리는 분상제 적용 물량이 줄어들 것으로 예상되면서 고가점 통장 경쟁도 더 치열할 것으로 예상된다.
"""

# %% [markdown]
# ### 1. 텍스트 전처리

# %%
pip install soynlp
# Out:
# Requirement already satisfied: soynlp in /opt/anaconda3/envs/Jooan_Lee/lib/python3.11/site-packages (0.0.493)
# Requirement already satisfied: numpy>=1.12.1 in /opt/anaconda3/envs/Jooan_Lee/lib/python3.11/site-packages (from soynlp) (2.1.3)
# Requirement already satisfied: psutil>=5.0.1 in /opt/anaconda3/envs/Jooan_Lee/lib/python3.11/site-packages (from soynlp) (5.9.0)
# Requirement already satisfied: scipy>=1.1.0 in /opt/anaconda3/envs/Jooan_Lee/lib/python3.11/site-packages (from soynlp) (1.15.2)
# Requirement already satisfied: scikit-learn>=0.20.0 in /opt/anaconda3/envs/Jooan_Lee/lib/python3.11/site-packages (from soynlp) (1.6.1)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/envs/Jooan_Lee/lib/python3.11/site-packages (from scikit-learn>=0.20.0->soynlp) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/envs/Jooan_Lee/lib/python3.11/site-packages (from scikit-learn>=0.20.0->soynlp) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import re
import pandas as pd
from soynlp.noun import LRNounExtractor_v2
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from konlpy.tag import Okt

# %%
# 1. 특수문자 및 [사진 출처 = ...] 제거
train_article_cleaned = re.sub(r'\[사진 출처.*?\]', '', train_article)
train_article_cleaned = re.sub(r'[^가-힣a-zA-Z0-9\s]', '', train_article_cleaned)

# %%
# 2. 고유명사 자동 추출 (soynlp 사용)
noun_extractor = LRNounExtractor_v2(verbose=True)
nouns = noun_extractor.train_extract([train_article_cleaned])

# 상위 고유명사 필터링 (빈도 기반)
proper_nouns = [noun for noun, score in nouns.items() if score.frequency >= 1.0]
print(f"추출된 고유명사: {proper_nouns}")

# 3. 고유명사 결합 처리 (공백 제거 → _로 결합)
for noun in proper_nouns:
    train_article_cleaned = train_article_cleaned.replace(noun, noun.replace(' ', '_'))

# 4. 형태소 분석 및 명사 추출 (Okt 사용)
okt = Okt()
tokens = okt.nouns(train_article_cleaned)

# 불용어 제거 및 한 글자 단어 제거
tokens = [token for token in tokens if len(token) > 1]

# 전처리 완료된 텍스트 확인
cleaned_article = ' '.join(tokens)
print(f"\n전처리 완료 텍스트:\n{cleaned_article}")
# Out:
# [Noun Extractor] use default predictors
# [Noun Extractor] num features: pos=3929, neg=2321, common=107
# [Noun Extractor] counting eojeols
# [EojeolCounter] n eojeol = 136 from 1 sents. mem=0.030 Gb
# [Noun Extractor] complete eojeol counter -> lr graph
# [Noun Extractor] has been trained. #eojeols=158, mem=0.031 Gb
# [Noun Extractor] batch prediction was completed for 66 words
# [Noun Extractor] checked compounds. discovered 1 compounds
# [Noun Extractor] postprocessing detaching_features : 19 -> 19
# [Noun Extractor] postprocessing ignore_features : 19 -> 19
# [Noun Extractor] postprocessing ignore_NJ : 19 -> 19
# [Noun Extractor] 19 nouns (1 compounds) with min frequency=1
# [Noun Extractor] flushing was done. mem=0.032 Gb
# [Noun Extractor] 30.38 % eojeols are covered
# 추출된 고유명사: ['레이크파크', '지난해', '84점', '당첨자', '분상제', '분양', '청약', '이상', '만점', '단지', '지역', '통장', '적용', '예상', '서울', '기', '대', '등', '청약통장']
#
# 전처리 완료 텍스트:
# 의왕 지구 대방 디에트르 레이크 파크 조감도 경기도 의왕시 분양 단지 올해 청약 통장 만점 당첨 만점 가구 이상 주택 기간 이상 유지 청약 지난 당첨 발표 의왕 지구 대방 디에트르 레이크 파크 만점 통장 만점 통장 전용 기타 지역 최저 최고 기록 단지 앞서 진행 순위 청약 가구 공급 특별 공급 제외 신청 분양 상한 적용 주변 시세 공급 가격 책정 관심 단지 분양 전용 기준 전용 기준 시작 국토교통부 거래 공개 시스템 인근 위치 의왕역 푸르지오 포레 전용 타입 지난해 거래 한편 지난해 단지 만점 통장 지역별 서울 경기 전북 서울 래미안 일리 래미안 에이치 대치 에델루이 상제 적용 분양 가가 시세 강남 아파트 집중 올해 로또 청약 상제 적용 물량 예상 가점 통장 경쟁 예상

# %% [markdown]
# ### 2. 벡터화 (DTM)

# %%
# 5. DTM 생성 (CountVectorizer 사용)
vectorizer = CountVectorizer(
    max_df=1.0,  # 일단 단일문서라 1로 설정
    min_df=1,   # 최소 1회 이상 등장한 단어만 포함 (일단 단일문서라서)
    # ngram_range=(1, 2),   # unigram + bigram
    stop_words=['에서', '그리고', '하지만', '때문에', '지난', '있다', '하는', '했다', '수']
)

dtm = vectorizer.fit_transform([cleaned_article])

# %% [markdown]
# ### 3. LDA 모델 학습

# %%
# 6. LDA 모델 학습
lda = LatentDirichletAllocation(
    n_components=7, 
    random_state=42
)
lda.fit(dtm)

# 7. 토픽별 주요 키워드 출력
terms = vectorizer.get_feature_names_out()
print("\n[토픽별 주요 키워드]")
for i, topic in enumerate(lda.components_):
    top_keywords = [terms[j] for j in topic.argsort()[-10:]]
    print(f"토픽 {i + 1}: {top_keywords}")
# Out:
# [토픽별 주요 키워드]
# 토픽 1: ['순위', '시스템', '시작', '신청', '푸르지오', '앞서', '에델루이', '에이치', '유지', '한편']
# 토픽 2: ['순위', '시스템', '시작', '신청', '푸르지오', '앞서', '에델루이', '에이치', '유지', '한편']
# 토픽 3: ['이상', '의왕', '공급', '적용', '전용', '청약', '분양', '단지', '만점', '통장']
# 토픽 4: ['순위', '시스템', '시작', '신청', '푸르지오', '앞서', '에델루이', '에이치', '유지', '한편']
# 토픽 5: ['순위', '시스템', '시작', '신청', '푸르지오', '앞서', '에델루이', '에이치', '유지', '한편']
# 토픽 6: ['순위', '시스템', '시작', '신청', '푸르지오', '앞서', '에델루이', '에이치', '유지', '한편']
# 토픽 7: ['순위', '시스템', '시작', '신청', '푸르지오', '앞서', '에델루이', '에이치', '유지', '한편']

# %%
# 8. 기사별 주요 토픽 점수 출력
doc_topic = lda.transform(dtm)
topic_names = ['교통', '시세차익', '입지', '경쟁률', '개발_호재', '대출', '공시가']

print("\n[기사별 토픽 비율]")
for i, score in enumerate(doc_topic[0]):
    print(f"{topic_names[i]}: {score:.4f}")

# 9. 주요 토픽 매핑
top_topic = doc_topic[0].argmax()
print(f"\n이 기사의 주요 토픽: {topic_names[top_topic]}")
# Out:
# [기사별 토픽 비율]
# 교통: 0.0012
# 시세차익: 0.0012
# 입지: 0.9927
# 경쟁률: 0.0012
# 개발_호재: 0.0012
# 대출: 0.0012
# 공시가: 0.0012
#
# 이 기사의 주요 토픽: 입지

# %% [markdown]
# ### 4. 결과 및 시각화

# %% [markdown]
# ## 매물 하나 지정해서 모든 기사내용으로 시도

# %%
# apartment 값이 같은 경우 content 내용 합치기
#combined_contents = df.groupby('apartment')['content'].apply(' '.join).reset_index()

# 결과 확인
#combined_contents.head()

# %%
# 0번째 아파트부터 시작
target_apartment = df.loc[0, 'apartment']

# 같은 apartment 값을 가진 content를 하나로 합치기
combined_content = ' '.join(df.loc[df['apartment'] == target_apartment, 'content'])

# 결과 확인
print(combined_content)
# Out:
# 의왕 월암지구 대방 디에트르 레이크파크 조감도. [사진 출처 = 대방건설]경기도 의왕시에서 분양된 단지에서 올해 첫 청약통장 만점 당첨자가 나왔다.만점인 84점을 받으려면 7인 가구 이상으로 무주택 기간 15년 이상을 유지해야 한다.13일 청약홈에 따르면 지난 8일 당첨자를 발표한 ‘의왕 월암지구 대방 디에트르 레이크파크’에서 84점 만점 통장이 나왔다.만점 통장은 전용 84㎡A 기타 지역에서 나왔다. 최저 47점, 최고 84점을 기록했다.이 단지는 앞서 진행된 1·2순위 청약에서 386가구 공급(특별공급 제외)에 1625명이 신청했다.분양가 상한제가 적용돼 주변 시세보다 공급가격이 낮게 책정된 점이 수요자들의 관심을 끌었다.단지 분양가는 전용 75㎡ 기준 5억4000만원대, 전용 84㎡ 기준 6억1000만원대부터 시작된다.국토교통부 실거래가 공개시스템에 따르면 인근 위치한 ‘의왕역 푸르지오 라포레’의 전용 84㎡D타입은 지난해 7월 7억5000만원에 거래됐다.한편 지난해에는 총 7개 단지에서 만점 통장이 나왔다. 지역별로 보면 서울 4개, 경기 2개, 전북 1개 등이다.서울에서는 ‘래미안 원베일리’, ‘래미안 원펜타스’, ‘디에이치 대치 에델루이’ 등 분상제가 적용돼 분양가가 시세보다 저렴하게 나왔던 강남3구 아파트에 집중됐다.올해는 이른바 ‘로또 청약’으로 불리는 분상제 적용 물량이 줄어들 것으로 예상되면서 고가점 
비롯해 GTX-D노선, 인천2호선 고양연장선 등이 추진 중이다.두진건설은 충북 청주시 송절동 일대에서 주상복합 아파트 '청주테크노폴리스하트리움더메트로’를 공급한다. 지하 3층, 지상 최고 49층, 4개동으로 전용 84~220㎡ 아파트 599가구와 전용 84㎡ 오피스텔 162실이 함께 들어선다. 청주 2 · 3 순환로를 통해 중부고속도로, 경부고속도로 진출입이 용이하다. 천안~청주국제공항 복선전철 북청주역이 2029년 신설될 예정이다.새해를  ...

# %%
# 텍스트 전처리

# 1. 특수문자 및 [사진 출처 = ...] 제거
combined_content_clean = re.sub(r'\[사진 출처.*?\]', '', combined_content)
combined_content_clean = re.sub(r'[^가-힣a-zA-Z0-9\s]', '', combined_content_clean)

# 2. 고유명사 자동 추출 (soynlp 사용)
noun_extractor = LRNounExtractor_v2(verbose=True)
nouns = noun_extractor.train_extract([combined_content_clean])

# 상위 고유명사 필터링 (빈도 기반)
proper_nouns = [noun for noun, score in nouns.items() if score.frequency >= 1.0]
print(f"추출된 고유명사: {proper_nouns}")

# 3. 고유명사 결합 처리 (공백 제거 → _로 결합)
for noun in proper_nouns:
    combined_content_clean = combined_content_clean.replace(noun, noun.replace(' ', '_'))

# 4. 형태소 분석 및 명사 추출 (Okt 사용)
okt = Okt()
tokens = okt.nouns(combined_content_clean)

# 불용어 제거 및 한 글자 단어 제거
tokens = [token for token in tokens if len(token) > 1]

# 전처리 완료된 텍스트 확인
cleaned_combined_content = ' '.join(tokens)
print(f"\n전처리 완료 텍스트:\n{cleaned_combined_content}")
# Out:
# [Noun Extractor] use default predictors
# [Noun Extractor] num features: pos=3929, neg=2321, common=107
# [Noun Extractor] counting eojeols
# [EojeolCounter] n eojeol = 676 from 1 sents. mem=0.037 Gb
# [Noun Extractor] complete eojeol counter -> lr graph
# [Noun Extractor] has been trained. #eojeols=1631, mem=0.065 Gb
# [Noun Extractor] batch prediction was completed for 244 words
# [Noun Extractor] checked compounds. discovered 6 compounds
# [Noun Extractor] postprocessing detaching_features : 73 -> 73
# [Noun Extractor] postprocessing ignore_features : 73 -> 70
# [Noun Extractor] postprocessing ignore_NJ : 70 -> 70
# [Noun Extractor] 70 nouns (6 compounds) with min frequency=1
# [Noun Extractor] flushing was done. mem=0.066 Gb
# [Noun Extractor] 30.78 % eojeols are covered
# 추출된 고유명사: ['부동산R114', '5천911가구', '5014가구', '분양가상한제', '나왔다만점', '검단신도시', '레이크파크', '강남3구', '기록했다', '선보인다', '비트코인', '원펜타스', '지난해', '4개동', '것이다', '아파트', '의왕시', '수도권', '84점', '당첨자', '장기화', '분상제', '분양', '이상', '예정', '청약', '적용', '진행', '책정', '시작', '기준', '단지', '인근', '최고', '경쟁', '공개', '전망', '규모', '전북', '3개', '지역', '전국', '위치', '상승', '목표', '우려', '통장', '물량', '집중', '주변', '개통', '서울', '예상', '새해', '조성', '내년', '주', '중', '통', '지', '내', '등', '위', '보', '초', '분양부동산R114', '물량부동산R114', '5014가구새해', '전망내년', '청약통장']
#
# 전처리 완료 텍스트:
수도권 광역급행 철도 노선 인천 호선 장선 추진 교통 편의 매우 업계 인천 연수구 옥련동 래미안 송도역 센트 리폴 경기 의왕시 의왕 지구 대방 트르 레이크 파크 청약 진행 부동산 첫째 신도시 밀리 리프 래미안 송도역 센트 리폴 분양 부동산 제공 새해 첫째 전국 단지 가구 분양 시작 부동산 내년 첫째 전국 단지 가구 일반 분양 가구 공급 신동아 건설 인천 서구 마전동 신도시 신도시 밀리 리프 단지 지하 지상 최고 전용 면적 가구 규모 개통 목표 인천 지하철 호선 장선 호수 공원 가칭 비롯 수도권 광역급행 철도 노선 인천 호선 장선 추진 교통 편의 매우 업계 인천 연수구 옥련동 래미안 송도역 센트 리폴 경기 의왕시 의왕 지구 대방 트르 레이크 파크 청약 진행 다한 다음 견본 주택 김두용 기자 견본주택 새해 초희 디자이너 서울 뉴스 지명 기자 다음 인천 서구 마전동 신도 시파 밀리 리프 비롯 전국 단지 분양 부동산 첫째 전국 단지 가구 일반 분양 가구 분양 진행 인천 연수구 옥련동 래미안 송도역 센트 리폴 경기 의왕시 의왕 대방 트르 레이크 파크 청약 진행 동아 건설 인천 서구 마전동 신도시 신도 시파 밀리 리프 분양 지하 지상 최고 전용 면적 가구 규모 조성 개통 목표 인천 지하철 호선 장선 호수 공원 가칭 비롯 노선 인천 호선 장선 추진 향후 대중교통 편의 향상 전망 개통 주변 상업 업무 시설 예정 단지 유치원 초등학교 부지 마주 공원 공원 조성 계획 주거 환경 건설 충북 청주시 흥덕구 송절동 번지 일원 청주 테크노 폴리스 하트 리움 메트로 분양 예정 지하 지상 최고 규모 주상 복합 아파트 전용 면적 아파트 가구 전용 면적 오피스텔 청주 순환로 통해 중부 고속도로 경부 고속도로 진출 천안 청주국제공항 복선전철 북청 주역 신설 예정 수혜 효과 기대 머티리얼즈 에어 플러스 생활 건강 청주 테크 ...

# %%
# 벡터화 - DTM 생성 (CountVectorizer 사용)
vectorizer = CountVectorizer(
    max_df=0.95,  # 일단 단일문서라 1로 설정
    min_df=2,   # 최소 1회 이상 등장한 단어만 포함 (일단 단일문서라서)
    # ngram_range=(1, 2),   # unigram + bigram
    stop_words=['에서', '그리고', '하지만', '때문에', '지난', '있다', '하는', '했다', '수']
)

dtm = vectorizer.fit_transform([cleaned_combined_content])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 9
#       1 # 벡터화 - DTM 생성 (CountVectorizer 사용)
#       2 vectorizer = CountVectorizer(
#       3     max_df=0.95,  # 일단 단일문서라 1로 설정
#       4     min_df=2,   # 최소 1회 이상 등장한 단어만 포함 (일단 단일문서라서)
#       5     # ngram_range=(1, 2),   # unigram + bigram
#       6     stop_words=['에서', '그리고', '하지만', '때문에', '지난', '있다', '하는', '했다', '수']
#       7 )
# ----> 9 dtm = vectorizer.fit_transform([cleaned_combined_content])
#
# File /opt/anaconda3/envs/Jooan_Lee/lib/python3.11/site-packages/sklearn/base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File /opt/anaconda3/envs/Jooan_Lee/lib/python3.11/site-packages/sklearn/feature_extraction/text.py:1386, in CountVectorizer.fit_transform(self, raw_documents, y)
#    1384 min_doc_count = min_df if isinstance(min_df, Integral) else min_df * n_doc
#    1385 if max_doc_count < min_doc_count:
# -> 1386     raise ValueError("max_df corresponds to < documents than min_df")
#    1387 if max_features is not None:
#    1388     X = self._sort_features(X, vocabulary)
#
# ValueError: max_df corresponds to < documents than min_df
